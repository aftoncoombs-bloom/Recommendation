# %%
import sys, os, time
sys.path.insert(1, '../../scripts/')
from s3_support import *

import pandas as pd

# %% [markdown]
# # load data

# %% [markdown]
# ## forms

# %%
q = '''select id, org, type, template from form'''
forms = redshift_query_read(q, schema='production')

# %%
forms['type'].unique()
# Out:
# array([1, 2, 3, 4, 5])

# %% [markdown]
# ## transactions

# %%
q = '''select * from transactions 
        where 
            status='A' and
            year>=2023'''
trans = redshift_query_read(q, schema='production')

# %%
trans.head(3)
# Out:
#          id     org    form status  amount  donations_amt  purchases_amt  \
# 0  18705059  437286  867448     A     25.0           25.0            0.0
# 1  18706899  436247  928464     A     19.0           19.0            0.0
# 2  18706291  436247  964981     A    100.0          100.0            0.0
#
#    events_amt  registrations_amt  events_tickets  ...  is_fraud  channel  \
# 0         0.0                0.0               0  ...     False        0
# 1         0.0                0.0               0  ...     False        0
# 2         0.0                0.0               0  ...     False        0
#
#    useragent  gift_assist_count  gift_assist_amt  qgiv_fee  platform  \
# 0       None                  0              0.0       0.0      None
# 1       None                  0              0.0       0.0      None
# 2       None                  0              0.0       0.0      None
#
#    recurring_origin is_new_form  isexpresscheckout
# 0                 0           0              False
# 1                 0           0              False
# 2                 0           0              False
#
# [3 rows x 47 columns]

# %%
drop_cols =['id', 'status', 'source_id', 'hour', 'day',
            'month', 'year', 'zip', 'state', 'email',
            'is_fraud']
trans = trans.drop(drop_cols, axis=1)

# %%
sum_cols = ['donations_count', 'purchases_count', 'events_count',
            'registrations_count', 'recurring', 'matchinggifts_count',
            'smspledge_count', 'auctionpurchase_count',
            'gift_assist_count', 'isexpresscheckout']

feat_grpd = trans.groupby('form')[sum_cols].sum().reset_index()
form_totals = trans.groupby('form')['qgiv_fee'].agg(['count', 'sum']).reset_index()

# %%
form_totals['fee_count'] = form_totals['count']
form_totals['fee_vol'] = form_totals['sum']
form_totals.drop(['count', 'sum'], axis=1, inplace=True)

feat_grpd = feat_grpd.merge(form_totals, on='form')

# %% [markdown]
# # analysis

# %% [markdown]
# ## correlation

# %%
flag_grpd = feat_grpd>1
flag_grpd['form'] = feat_grpd['form']
flag_grpd['fee_vol'] = feat_grpd['fee_vol']
flag_grpd['fee_count'] = feat_grpd['fee_count']
flag_grpd = flag_grpd.merge(forms[['id', 'type']], left_on='form', right_on='id').drop('id', axis=1)
flag_grpd.head()
# Out:
#    form  donations_count  purchases_count  events_count  registrations_count  \
# 0     1             True            False          True                False
# 1     3             True            False          True                False
# 2     9            False            False         False                False
# 3    11             True            False         False                False
# 4    14             True            False         False                False
#
#    recurring  matchinggifts_count  smspledge_count  auctionpurchase_count  \
# 0       True                False            False                  False
# 1       True                False            False                  False
# 2       True                False            False                  False
# 3       True                False            False                  False
# 4       True                False            False                  False
#
#    gift_assist_count  isexpresscheckout  fee_count   fee_vol  type
# 0               True              False       2892  15650.62     1
# 1               True              False        657   5795.78     1
# 2              False              False          1      5.85     1
# 3              False              False         55    806.02     1
# 4               True              False        293   3233.37     1

# %%
flag_grpd.drop(['form', 'type'], axis=1).corr()[['fee_count', 'fee_vol']]
# Out:
#                        fee_count   fee_vol
# donations_count         0.040582  0.064206
# purchases_count         0.006991  0.032437
# events_count           -0.005651  0.026024
# registrations_count     0.021603  0.035950
# recurring               0.071783  0.072329
# matchinggifts_count          NaN       NaN
# smspledge_count              NaN       NaN
# auctionpurchase_count  -0.000992  0.049088
# gift_assist_count       0.032311  0.066992
# isexpresscheckout       0.026939  0.035579
# fee_count               1.000000  0.476524
# fee_vol                 0.476524  1.000000

# %% [markdown]
# ## form types

# %%
flag_grpd['fee_vol'].agg(['mean', 'median'])
# Out:
# mean      679.199206
# median     71.450000
# Name: fee_vol, dtype: float64

# %%
flag_grpd.groupby('type')['fee_vol'].agg(['mean', 'median', 'count']).reset_index()
# Out:
#    type         mean   median  count
# 0     1   602.747516   54.660  23527
# 1     3   883.505179  179.855   3524
# 2     5  1512.819498  760.975   1294

# %% [markdown]
# ## feature averages

# %%
grp_cols = [c for c in flag_grpd.columns if c not in ['form', 'fee_count', 'fee_vol', 'type']]
fee_groups = flag_grpd.groupby(grp_cols)[['fee_count', 'fee_vol']].sum().reset_index()
fee_groups['fee_vol_per_form'] = fee_groups['fee_vol'] / fee_groups['fee_count']

# %%
d = []
for c in grp_cols:
    mn = flag_grpd[flag_grpd[c]]['fee_vol'].mean()
    mdn = flag_grpd[flag_grpd[c]]['fee_vol'].median()
    len_group = len(flag_grpd[flag_grpd[c]]['form'].unique())
    d.append({
        'feature': c.replace('_count', ''),
        'count': len_group,
        'mean fees': mn,
        'median fees': mdn
    })
pd.DataFrame(d).sort_values('median fees', ascending=False)
# Out:
#              feature  count    mean fees  median fees
# 7    auctionpurchase    963  1872.773666     1082.080
# 1          purchases    619  1669.103473      850.100
# 3      registrations   2288  1232.402832      408.335
# 9  isexpresscheckout    625  1759.663408      246.160
# 2             events   6863   889.150396      204.370
# 8        gift_assist  14312   981.683266      193.495
# 0          donations  19966   868.861195      116.350
# 4          recurring   9603  1139.957201      107.830
# 5      matchinggifts      0          NaN          NaN
# 6          smspledge      0          NaN          NaN

# %%
fee_groups[fee_groups[c]]
# Out:
#     donations_count  purchases_count  events_count  registrations_count  \
# 5             False            False         False                False
# 21             True            False         False                False
# 23             True            False         False                False
# 26             True            False         False                False
# 28             True            False         False                False
# 35             True            False          True                False
# 39             True            False          True                False
# 41             True            False          True                False
#
#     recurring  matchinggifts_count  smspledge_count  auctionpurchase_count  \
# 5        True                False            False                  False
# 21      False                False            False                  False
# 23      False                False            False                  False
# 26       True                False            False                  False
# 28       True                False            False                  False
# 35      False                False            False                  False
# 39       True                False            False                  False
# 41       True                False            False                  False
#
#     gift_assist_count  isexpresscheckout  fee_count    fee_vol  \
# 5                True               True         56     153.03
# 21              False               True       2783    9027.00
# 23               True               True       5793   43591.24
# 26              False               True      45089   66919.94
# 28               True               True     248671  773987.72
# 35               True               True       4944   42117.28
# 39              False               True       8044   56238.24
# 41               True               True      24245  107755.18
#
#     fee_vol_per_form
# 5           2.732679
# 21          3.243622
# 23          7.524813
# 26          1.484174
# 28          3.112497
# 35          8.518867
# 39          6.991328
# 41          4.444429

# %%
fee_groups[fee_groups['fee_count']>10].sort_values('fee_vol_per_form', ascending=False).head(10)
# Out:
#     donations_count  purchases_count  events_count  registrations_count  \
# 42             True             True         False                False
# 43             True             True         False                False
# 18            False             True          True                False
# 17            False             True          True                False
# 37             True            False          True                False
# 50             True             True          True                False
# 52             True             True          True                False
# 51             True             True          True                False
# 36             True            False          True                False
# 0             False            False         False                False
#
#     recurring  matchinggifts_count  smspledge_count  auctionpurchase_count  \
# 42      False                False            False                  False
# 43      False                False            False                  False
# 18      False                False            False                   True
# 17      False                False            False                  False
# 37      False                False            False                   True
# 50      False                False            False                  False
# 52      False                False            False                   True
# 51      False                False            False                   True
# 36      False                False            False                   True
# 0       False                False            False                  False
#
#     gift_assist_count  isexpresscheckout  fee_count     fee_vol  \
# 42              False              False       1105    30337.57
# 43               True              False       2164    39781.15
# 18              False              False        857    13669.18
# 17               True              False         32      509.13
# 37               True              False      82556  1032829.08
# 50               True              False        470     5233.76
# 52               True              False      35851   374922.66
# 51              False              False       4282    44327.31
# 36              False              False      14785   147542.30
# 0               False              False       3281    32357.62
#
#     fee_vol_per_form
# 42         27.454814
# 43         18.383156
# 18         15.950035
# 17         15.910312
# 37         12.510648
# 50         11.135660
# 52         10.457802
# 51         10.352011
# 36          9.979188
# 0           9.862121
