# %%
import requests, json
import pandas as pd

# %%
URL = 'https://analyticsapi.qgiv.com/amounts_rec_data/'
URL_HTTP = 'http://52.2.34.90:8890/amounts_recom/'

DATA = {'key': 'tIHLM2vNlBwvlZlqdKy8'}

# %%
r = requests.post(URL, json=DATA)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-4c8d0b0541b1> in <module>
#       1 r = requests.post(URL, json=DATA)
# ----> 2 r.rsp
#
# AttributeError: 'Response' object has no attribute 'rsp'

# %%
r.text[:500]
# Out:
# '{\n  "data": [\n    {\n      "annual": 500.0,\n      "biannual": "null",\n      "bimonth": "null",\n      "count": 7,\n      "is_christmas": false,\n      "is_newyears": false,\n      "month": 25.0,\n      "onetime": 105.0,\n      "platform": "Windows",\n      "quarter": "null",\n      "state": "VA",\n      "week": "null",\n      "zip": 801\n    },\n    {\n      "annual": "null",\n      "biannual": "null",\n      "bimonth": "null",\n      "count": 11,\n      "is_christmas": false,\n      "is_newyears": false,\n      "m'
