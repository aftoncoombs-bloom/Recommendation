# %%
import pandas as pd

import sys
sys.path.insert(1, '../../../scripts/')
from s3_support import *

# %%
BUCKET = "segment-export"

# %%
list_files(BUCKET, sub_directory="segment-logs")
# Out:
# segment-logs/ (0MB)
# --------------------------------------------------
# Bucket segment-export contains 1 files (0.0GB)
# ['segment-logs/']

# %%
s3_resource = init_s3_resource()
bucket_resource = s3_resource.Bucket(BUCKET)
for o in bucket_resource.objects.filter(Prefix="segment-logs").all():
    print(o.key)
# Out:
# segment-logs/
