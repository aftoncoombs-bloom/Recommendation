# %%
import pandas as pd
import sys

sys.path.insert(1, '../scripts/')
from s3_support import *

# %% [markdown]
# # Load Data From S3

# %%
url = get_file_url("sfc-export", "Event.csv")

df = pd.read_csv(url, encoding="ISO-8859-1", low_memory=False)

# %% [markdown]
# # Drop Irrelevant Columns

# %%
drop_cols = ["Location", "IsPrivate", "ShowAs", "IsDeleted", "IsChild", "IsRecurrence", "RecurrenceStartDateTime", 
             "RecurrenceEndDateOnly", "RecurrenceTimeZoneSidKey", "RecurrenceType", "RecurrenceInterval", 
             "RecurrenceDayOfWeekMask", "RecurrenceDayOfMonth", "RecurrenceInstance", "RecurrenceMonthOfYear", 
             "ReminderDateTime", "IsReminderSet", "RecurrenceActivityId", "bizible2__BizibleId__c", 
             "bizible2__Bizible_Touchpoint_Date__c"]

df.drop(drop_cols, axis=1, inplace=True)
# df['CreatedDate'] = pd.to_datetime(df['CreatedDate'])
# after_2016 = df[df['CreatedDate'].dt.year >= 2016]
# len(after_2016)

# %% [markdown]
# # Exploratory Analysis

# %%
print("{} rows".format(len(df)))
print("Columns ({}):".format(len(df.columns)))
print(list(df.columns))
df.describe()
# Out:
# 43663 rows
# Columns (26):
# ['Id', 'WhoId', 'WhatId', 'WhoCount', 'WhatCount', 'Subject', 'IsAllDayEvent', 'ActivityDateTime', 'ActivityDate', 'DurationInMinutes', 'Description', 'AccountId', 'OwnerId', 'Type', 'IsGroupEvent', 'GroupEventType', 'CreatedDate', 'CreatedById', 'LastModifiedDate', 'LastModifiedById', 'SystemModstamp', 'IsArchived', 'ProposedEventTimeframe', 'Time_Zone__c', 'Import2_Id__c', 'Activity_Type__c']
#            WhoCount     WhatCount  IsAllDayEvent  DurationInMinutes  \
# count  43663.000000  43663.000000   43663.000000       43663.000000
# mean       0.810228      0.189932       0.000115           5.675515
# std        0.394280      0.392252       0.010701          88.439409
# min        0.000000      0.000000       0.000000           0.000000
# 25%        1.000000      0.000000       0.000000           0.000000
# 50%        1.000000      0.000000       0.000000           0.000000
# 75%        1.000000      0.000000       0.000000           0.000000
# max        2.000000      1.000000       1.000000        1440.000000
#
#        IsGroupEvent  GroupEventType    IsArchived
# count     78.000000       78.000000  43663.000000
# mean       0.948718        0.948718      0.913359
# std        0.318170        0.318170      0.281311
# min        0.000000        0.000000      0.000000
# 25%        1.000000        1.000000      1.000000
# 50%        1.000000        1.000000      1.000000
# 75%        1.000000        1.000000      1.000000
# max        2.000000        2.000000      1.000000

# %%
def print_column_descriptions():
    ids_to_ignore = ["Id", "WhoId", "WhatId"]
    group_columns = []

    for c in df.columns:
        if c not in ids_to_ignore:
            print(c)
            print(df[c].describe())
            print("\n")
            
# print_column_descriptions()

# %%
# df['Description']

# %%
df['Type'].value_counts()
# Out:
# Call            35
# Demo            24
# Meeting         10
# Email            1
# Cancellation     1
# Name: Type, dtype: int64

# %%
# df['Subject']

# %%
df['Type'].fillna("None").value_counts(normalize=True)
# Out:
# None            0.998374
# Call            0.000802
# Demo            0.000550
# Meeting         0.000229
# Email           0.000023
# Cancellation    0.000023
# Name: Type, dtype: float64

# %%
df[df['Type'].isna()]['Description'].tail(25)
# Out:
# 43638                                                                             Spoke with her at their Bike Denver membership drive. She seemed very interested and asked for an email. They are currently using Acceptiva and aren't very happy with the service. Also, they will be redoing their website and would like more information.  I should offer them a discount on the startup cost, maybe 1/2 or full off. See how it goes. Others from Bike Denver were also interested in Qgiv, they were very receptive.
# 43639                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Left a message.
# 43640                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Left a message.
# 43641                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Left a message.
# 43642                                                                                                                                                                                                                                                                                                                                                                                                                                                                          They are not ready yet, still need more time.
# 43643                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Left a message.
# 43644                                                                                                                                                                                                                                                                                                                                                                                                                                                                   He is interested in a demo. Email back about a time.
# 43645                                                                                                                                                                                                                                                                                                                                                                               501c3 and 501c19 (military membership). They are real small, very small membership and donations around $6000. Elavaon Merchant account.
# 43646                                                                                                                                                                                                                                                                                                                                                                                                                                                                                they currently have a stand alone kiosk
# 43647                                                                                                                                                                                                                                                                                                                                                                                                                                                                             isn't in the office yet.  call back later.
# 43648                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Left a message.
# 43649                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Left a message.
# 43650                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Left a message.
# 43651                                                                                                                                                                                                          She called in and asked about our service. She said that she had been looking into a few other services and was comparing them for now. She didn't give me a good time to call back and said she would contact me. They are looking for customizable pages.  Acceptiva was the one competitor she brought up.
# 43652                                                                                                                                                                                                                                                                                                                                                                                                                                      they want to go with us but are not ready and will get back with us when they are
# 43653                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           left message
# 43654                                                                                                                                                                                                                                                                                                                                                                           they will be in touch when they have their 501c3 but she was fine with a call in a month or so... she said they will be in touch before then
# 43655                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           left message
# 43656                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         not interested
# 43657    Jennifer:  I received the PCI assessment.  Tom is out of the office today, but I will have him sign the questionnaire and fax it back to you.  I am attempting to change names and email addresses on it since Beth is no longer with us.  I am the new bookkeeper and my name is Mary Mudler, email address is mary@judgementhouse.org.  I was in the profile for QGive and I changed the email settings on it and noticed that the questionnaire was not updated.  Give me a call if you have any questions.  ...
# 43658                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                left vm
# 43659                                                                                                                                                                                                                                                                                                                                                                                                                                                                       left vm to see if she read info forwarded by Ed.
# 43660                                                                                                                                                                                                                                                                                                                                                                                                                                                        Ed forwarded my email to her.  This will be the contact person.
# 43661                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    NaN
# 43662                                                                                                                                                                                                                                                                                    Hi Karlyn,  Thank you for selecting a date and time.    In a few minutes I will be sending you the demonstration credentials to access the Go To Meeting.  Feel free to contact me if you have any questions.  Thanks, Aaron Liford
# Name: Description, dtype: object

# %% [markdown]
# _@TODO_ Need to tag types from descriptions. 99% of types are not tagged, but lots of descriptive text.
#
# Task Types:
#    - Email
#    - Call                      67301
#    - Pre-Demo Follow Up        33352
#    - Post-Demo Follow Up       13696
#    - Prepared Materials         3491
#    - Web Demo Completed         2339
#    - None                       2333
#    - Lead Qualification         1760
#    - Lead Submitted Form        1571
#    - Initial Contact            1568
#    - One Pager Campaign         1162
#    - Conversation               1023 Should this be moved to call?
#    - Demo Scheduled              842
#    - 60_Day_Follow_Up_Call       401
#    - Demo/Meeting                202
#    - Recovery                     72
#    - Live Demo Completed          58
#    - Phone Call                    1
#    - Training                      1
#    - COS - 45 Day Call             1

# %% [markdown]
# # Infer Type From Data

# %%
email_keywords = [
    'email',
    'dear',
    'new customer inquiry',
    'thanks for your interest',
    'let me know if you have any',
    'fwd',
    'fw'
]

call_keywords = [
    'call',
    'left a message',
    'left message',
    'left him a message',
    'left her a message',
    'left msg',
    'vm',
    'voice mail',
    'spoke with',
    'number not in',
    '# not in',
    'number is not in',
    '# is not in',
    'no answer',
    'on hold',
    'isn\'t in the office',
    'not in the office',
    'out of the office',
    'out of office',
    'spoke to',
    'not in on',
    'was not in',
    'this number was',
    'number does not work',
    'talked with',
    'could not leave a message',
    'mailbox is full',
    'should be in the office',
    'he was in a meeting',
    'he was going into a meeting',
    '# is for',
    'that answered',
    'number is wrong',
    'busy signal',
    'numbers are for',
    'disconnected #',
    'kept ringing',
    'was in the middle of a meeting',
    'took my number',
    'could not get through',
    'wasn\'t home',
    'not in their office',
    'not available to talk',
    'left another message',
    'left follow up message',
    'left a general message',
    'just continued to ring',
    'busy again',
    'busy all day',
    'chatted with',
    'checked in with',
    'talked to',
    'talked with',
    'spoke with',
    'out of town',
    'out of office',
    'get back to'
]

pre_demo_follow_up_keywords = [
    'pre demo follow up'
]

post_demo_follow_up_keywords = [
    'post demo follow up'
]

demo_completed_keywords = [
    'demo completed',
    'completed demo',
    'the demo',
    'in person demo',
    'good demo',
    'bad demo',
    'demo went',
    'they seemed very happy with the system',
    'went through demo',
    'went through a demo',
    'walked through a demo'
]

prepared_materials_keywords = [
    'prepared materials'
]

web_demo_completed_keywords = [
    'web demo completed',
    'please join my meeting from your computer'
]

lead_qualification_keywords = [

]

lead_submitted_form_keywords = [
    'submitted form',
    'contact us',
    'recieved your message',
    'request web lead'
]

initial_contact_keywords = [
    'initial contact',
    'main contact'
]

one_pager_campaign_keywords = [
    'one pager',
    'one-pager'
]

demo_scheduled_keywords = [
    'demo scheduled',
    'scheduled demo',
    'scheduled a demo',
    'set up a meeting',
    'would like to see a demo',
    'moving forward with a demo',
    'demo rescheduled',
    'would like a demo',
    'interested in a demo',
    'would like a comparison',
    'signed up for a demo',
    'would like to go through a demo',
    'would like to see our service',
    'on for a demo',
    'on for a hobnob demo',
    'scheduled a phone meeting',
    'would like to set up a hobnob demo',
    'wants to talk about',
    'wants to see',
    'wants a demo'
]

sixty_day_follow_up_keywords = [
    '60 day follow up',
    'sixty day follow up',
    'sign up follow up',
    'signup follow up',
    '60 day checkin',
    'signup form'
]

training_keywords = [
    'training'
]

interested_keywords = [
    'are interested',
    'was interested',
    'very interested',
    'is interested',
    'interested in',
    'wants more information',
    'will be discussing',
    'might be interested',
    'seemed interested',
    'still interested',
    'would like to learn more',
    'would like info',
    'wants more info'
]

not_interested_keywords = [
    'not interested',
    'no interest',
    'they backed out',
    'no longer interested',
    'doesn\'t seem interested',
    'doesn\'t sound too interested',
    'went with',
    'not that interested',
    'doesn\'t think it would be well received',
    'satisfied with authorize.net',
    'does not think they will move forward',
    'using paypal',
    'staying with',
    'using donor perfect',
    'custom solution',
    'no longer a direction that they are going',
    'decided to go in a different direction',
    'moving in a different direction',
    'currently using blackbaud',
    'are currently ok with',
    'using vanco',
    'using shelby',
    'currently satisfied with their solution',
    'she made the decision on another vendor',
    'hung up on me',
    'he hung up',
    'she hung up',
    'currently using',
    'too expensive for them'
    'using classy',
    'using stay classy',
    'using acs',
    'are not looking to change',
    'happy with their event service',
    'isn\'t a good fit',
    'have decided to go with',
    'satisfied with their current solution',
    'decided not to move forward',
    'decided to move forward with another',
    'using fellowship one',
    'doesn\'t seem to interested',
    'looking into different services',
    'using secure give'
    
]

# TODO: Maybe break these up?
not_ready_keywords = [
    'not ready',
    'needs some time',
    'they will be able to move forward in',
    'asked me to check back',
    'contact me again in',
    'check back with',
    'give her at least a',
    'check back',
    'asked for a day',
    'asked for a week',
    'asked for a couple of weeks',
    'on vacation',
    'out for the next',
    'will get back with me',
    'isn\'t ready'
]

# TODO: Maybe break these up?
sale_closed_keywords = [
    'moving forward',
    'we finalized things',
    'application received',
    'application has been received',
    'have been approved',
    'they should be all set up',
    'setting up an account',
    'start the application process',
    'they are live',
    'they are now live',
    'going through the signup',
    'going through signup',
    'in the signup process',
    'go through the signup',
    'page is finished',
    'they are submitted',
    'they are signed up',
    'they are all signed up',
    'will be sending their information in',
    'being submitted right now',
    'going through the application right now',
    'going to sign up',
    'ready to move forward',
    'going with qgiv',
    'they are activated',
    'they are signing up',
    'want to move forward with qgiv',
    'completed sign up',
    'application submitted',
    'received application',
    'sent online application',
    'signup process',
    'approval process',
    'gone through signup'
]

client_missed_demo_keywords = [
    'missed demo',
    'no show for demo',
    'no show for the hobnob demo'
]

webinar_keywords = [
    'webinar'
]

cancellation_keywords = [
    'cancelled',
    'cancellation',
    'cancel'
]

downgrade_keywords = [
    'downgrade',
    'downgraded',
    'downgrading',
    'from grow to start',
    'from engage to start'
]

upgrade_keywords = [
    'upgrade',
    'upgraded',
    'upgrading'
]

kiosk_activity_keywords = [
    'kiosk'
]

mobile_vt_activity = [
    'mobile vt activity'
]

page_skin_keywords = [
    'page skin',
    'page skinning',
    'page skinned'
]

tshirt_campaign_keywords = [
    'tshirt campaign'
]

control_panel_migration_keywords = [
    'new control panel',
    'migrated to new cp',
    'switched control panel',
    'switched cp'
]

noise_keywords = [
    'birthday cake',
    'town hall meeting',
    'group insurance',
    'try back',
    'contact me back',
    'will be back'
]

meeting_keywords = [
    'meeting with',
    'meeting on',
    'meeting for',
    'met with'
]


def infer_type(r):
    if r['Type'].lower() == 'demo':
        return 'Demo Completed'
    elif r['Type'] != 'None': 
        return r['Type']
         
    def contains(keywords):
        subject = str(r['Subject']).lower()
        description = str(r['Description']).lower()
        
        return any(keyword in subject for keyword in keywords) or any(keyword in description for keyword in keywords)
    
    if contains(tshirt_campaign_keywords):
        return 'T-Shirt Campaign'
    elif contains(control_panel_migration_keywords):
        return 'Control Panel Migration'
    elif contains(pre_demo_follow_up_keywords):
        return 'Pre-Demo Follow Up'
    elif contains(post_demo_follow_up_keywords):
        return 'Post-Demo Follow Up'
    elif contains(demo_completed_keywords) or contains(web_demo_completed_keywords):
        return 'Demo Completed'
    elif contains(prepared_materials_keywords):
        return 'Prepared Materials'
    elif contains(lead_qualification_keywords):
        return 'Lead Qualification'
    elif contains(lead_submitted_form_keywords):
        return 'Lead Submitted Form'
    elif contains(initial_contact_keywords):
        return 'Initial Contact'
    elif contains(one_pager_campaign_keywords):
        return 'One Pager Campaign'
    elif contains(demo_scheduled_keywords):
        return 'Demo Scheduled'
    elif contains(sixty_day_follow_up_keywords):
        return '60 Day Follow Up'
    elif contains(training_keywords):
        return 'Training'
    elif contains(interested_keywords):
        return 'Interested'
    elif contains(not_interested_keywords):
        return 'Not Interested'
    elif contains(not_ready_keywords):
        return 'Not Ready'
    elif contains(sale_closed_keywords):
        return 'Sale Closed'
    elif contains(client_missed_demo_keywords):
        return 'Client Missed Demo'
    elif contains(webinar_keywords):
        return 'Webinar'
    elif contains(cancellation_keywords):
        return 'Cancellation'
    elif contains(downgrade_keywords):
        return 'Downgrade'
    elif contains(upgrade_keywords):
        return 'Upgrade'
    elif contains(kiosk_activity_keywords):
        return 'Kiosk Activity'
    elif contains(mobile_vt_activity):
        return 'Mobile VT Activity'
    elif contains(page_skin_keywords):
        return 'Page Skin'
    elif contains(email_keywords):
        return 'Email'
    elif contains(call_keywords):
        return 'Call'
    elif contains(meeting_keywords):
        return 'Meeting'
    elif contains(noise_keywords):
        return 'Noise'
    else:
        return 'None'

# %%
df['Type'].fillna("None", inplace=True)
df['Type'] = df.apply(infer_type, axis=1)

# %%
df['Type'].fillna("None").value_counts(normalize=True)
# Out:
# Call                       0.502714
# None                       0.167510
# Training                   0.048989
# Interested                 0.047706
# Email                      0.045164
# Demo Completed             0.034949
# Kiosk Activity             0.034377
# Not Interested             0.028491
# Sale Closed                0.022330
# Demo Scheduled             0.014452
# Not Ready                  0.012184
# Cancellation               0.010489
# Downgrade                  0.009001
# Upgrade                    0.007191
# Mobile VT Activity         0.002886
# Meeting                    0.002222
# Control Panel Migration    0.001970
# Initial Contact            0.001947
# Lead Submitted Form        0.001672
# T-Shirt Campaign           0.001397
# Noise                      0.001237
# Webinar                    0.000435
# Client Missed Demo         0.000321
# Page Skin                  0.000275
# 60 Day Follow Up           0.000092
# Name: Type, dtype: float64

# %%
pd.set_option('display.max_colwidth', 500)
df[df['Type']=='None'][['Subject', 'Description', 'Type']].tail(100)
# Out:
#                                                                                                                                                                                                                                                                Subject  \
# 42887                                                                                                                                                                           Note: Received the application - let Kris know we were missing a couple of signatures.
# 42889                                                                                                                                                                                                               Note: Is no longer there. Kristi has replaced her.
# 42899                                                                                                                                                                                                                   Note: He doesn't deal with anything web based.
# 42901                                                                                                                                                                                                                                           Note: office is closed
# 42903                                                                                                                                                                                                                          Note: using authorize.net it looks like
# 42921                                                                                                                             Note: He is not the decision maker but said that if they are looking to move forward at some point they will get in contact with me.
# 42923                                                                                                                                                                   Note: Using RaisersEdge - brand new to them. However, they are always looking for new options.
# 42941                                                                                                                     Note: That went very well and he thinks he should be able to convince the board to go with us... he asked for a rate card and an application
# 42942                          Note: comments: We are starting an online donation system, where members will sign up to donate at least $10 every month each month. Will this system also be able to accomodate online purchases, for example selling t-shirts online?
# 42944                                                      Note: Sarah was having issues with the static event URL's asking for ADDITIONAL information and then Participant Information x's the number of tickets purchased. This has been resolved, I let Sarah know.
# 42953                                                                                                                                                                                                                         Note: the application has been corrected
# 42967                                                                                                                                                                                                 Note: Just waiting on the IRS letter. Katrina is contacting him.
# 42968                                                                                                                                                                          Note: He seems to be sending in everything today. Katrina has been in contact with him.
# 42974                                                                                                                                                                                            Note: Still working with Dottie and getting the chase account set up.
# 42975                                                                                                                                                                               Note: Waiting on their gateway information. But they will get that to dottie soon.
# 42976                                                                                                                                                                                                                                 Note: Still working with Dottie.
# 42977                                                                                                                                                                                               Note: Still waiting on them to provide some merchant account info.
# 42982                                                                                                                                                                           Note: Had a great visit at the newman center. They want to set up a demo. Around noon.
# 42989                                                                                                             Note: Said he just got back in from vacation. He will talk with the others this week and said I could follow up on Friday if I didn't hear from him.
# 43003                                                                                                                                                                                                                      Note: No one was in the office at the time.
# 43019                                                                                                                                                           Note: i walked her through editing the recurring payment she was trying to edit and she was very happy
# 43039                                                                                                                                                                                                   Note: uses networkmerchants.com . the form is a 3 step process
# 43048                                                                                                                                                                                                 Note: i got in touch with him and is date of birth is 09/19/1977
# 43057                                                                                                                               Note: She doesn't have any updates today. They are having a meeting today so we can discuss this a little further later this week.
# 43062                                                                                                                                                                                                                           Note: just got one with fellowship one
# 43077                                                                                                                                                                                                  Note: I need to schedule a demo with Tom for tomorrow afternoon
# 43083                                                                                                                                                                                                                              Note: we rescheduled for 3:30pm EST
# 43084                                                                                                                                                Note: comments: Nothing specific at the moment. Would like to get a demonstration of your service & its features.
# 43086                                                                                                                                                                                                                                Note: She is working with Dottie.
# 43094                                                                                                                                                                                                                                        Note: No show for a demo.
# ...                                                                                                                                                                                                                                                                ...
# 43309                                                                                                                                                                                        Note: He has everything in and Jennifer will be talking with him shortly.
# 43310                                                                                                                                                                Note: he is going to the bank today to check on the status. he will send it in as soon as he can.
# 43311                                                                                                                                                                                                                                   Note: he asked about QR codes.
# 43321                                                                                                                                                                           Note: Heartland Community Church has completed their information aaron.liford@qgiv.com
# 43328                                                                                                                                                                                                                      Note: she is uploading the documents today.
# 43331                                                                                                                                                    Note: We can provide them with a invoice during the setup process. I added the notes into their demo account.
# 43332                                                                                                                                                                                        Note: she wanted to know if we could provide an invoice of the setup fee.
# 43341                                                                                                                                                                       Note: I just remembered that they are on spring break and that is why she isn't answering.
# 43350                                                                                                                                                                                                            Note: Jennifer is going to touch base with her today.
# 43354                                                                                                                                                   Note: Jen left me a message about setting up the Quickbooks and Salesforce integration on their trial account.
# 43370                  Note: Left Bill a message regarding Hobnob and asking if they would entertain the idea of switching event registration systems. They are currently on active.com as their event is showcased as more of a run event as opposed to a fundraiser.
# 43380                                                                                                                                                                                     Note: She is still needing to send in the application and filling documents.
# 43381                                                                                                                                                                                                               Note: Wants us to sell demographic Demo to clients
# 43412  Note: I am running in a 5K and collecting donations to help my cousin-in-law raise money for brain cancer surgery he needs in Boston, which the UK will not pay for. I live in California and will be accepting donations from US and overseas. How do I go ...
# 43418                                                                                                                                                                                                   Note: Said that the new pastor isn't in to that type of stuff.
# 43419                                                          Note: The church just found a new pastor. He is supposed to be in today. If everyone at the church likes him then he will start on the 31st of March. She would like for me to follow up with her then.
# 43420  Note: She brought up to the finance committee but hasn't gone any further because they only have a interim pastor. The new pastor starts in December. They don't want to make any big changes until he takes over and gets comfortable with his position. Sh...
# 43457                                                                                                                                                                                                      Note: We won't be able to hold the renewal fee for 2 years.
# 43459  Note: The standard processing volume would have to be $500k to consider giving them a discount. However, they don't even come close to that. Sarah sounded somewhat disappointed. However, they will be researching other products out there and will touch ...
# 43461                                                                                                                                                     Note: She will be forwarding me some information in regards to the processing volume for the previous event.
# 43462                          Note: They bring in over a million dollars per year. I need to know how much they raise per event. Based off of that we could offer them a waiver on the renewal fee. I need to mention that we will throw in the Qgiv product in free.
# 43506                                                                                                                                                                            Note: Bank letter was faxed in yesterday - submitted to GMS with Application for ACH.
# 43521                                                                                                                                   Note: she said that Susan would be the one to deal with about setting up a merchant account or tying into the existing account
# 43535                                                                                                                                                                                                               Note: Activated international addresses per Irene.
# 43538  Note: there was a little confusion about a direct integration through Intuit Merchant Services but apparently that was with their donor management system and not Entengo so they are ready to go now with a complete Qgiv setup including the merchant acco...
# 43556                                                                             Note: she was busy but told me she was looking for something that is free... ha... I told her i would send her the rate card and she could get back with me if she had any questions
# 43563                                                                                                                                                                                                                                         Note: comments: pet name
# 43568                                                                              Note: Said that the BluePay reps will still need some information from them and he is planning on talking with them today. Said that they should be set up by the end of this week.
# 43607                                                                                                                                                                                           Note: Sent Ellen and Joan a Channel Partner Agreement for their review
# 43645                                                                                                                   Note: 501c3 and 501c19 (military membership). They are real small, very small membership and donations around $6000. Elavaon Merchant account.
#
#                                                                                                                                                                                                                                                                                                                                                                                               Description  \
# 42887                                                                                                                                                                                                                                                                                                                    Received the application - let Kris know we were missing a couple of signatures.
# 42889                                                                                                                                                                                                                                                                                                                                                       Is no longer there.  Kristi has replaced her.
# 42899                                                                                                                                                                                                                                                                                                                                                            He doesn't deal with anything web based.
# 42901                                                                                                                                                                                                                                                                                                                                                                                    office is closed
# 42903                                                                                                                                                                                                                                                                                                                                                                   using authorize.net it looks like
# 42921                                                                                                                                                                                                                                                                      He is not the decision maker but said that if they are looking to move forward at some point they will get in contact with me.
# 42923                                                                                                                                                                                                                                                                                                            Using RaisersEdge - brand new to them. However, they are always looking for new options.
# 42941                                                                                                                                                                                                                                                              That went very well and he thinks he should be able to convince the board to go with us... he asked for a rate card and an application
# 42942                                                                                                                                                                  comments: We are starting an online donation system, where members will sign up to donate at least $10 every month each month.  Will this system also be able to accomodate online purchases, for example selling t-shirts online?
# 42944                                                                                                                                                                                               Sarah was having issues with the static event URL's asking for ADDITIONAL information and then Participant Information x's the number of tickets purchased. This has been resolved, I let Sarah know.
# 42953                                                                                                                                                                                                                                                                                                                                                                  the application has been corrected
# 42967                                                                                                                                                                                                                                                                                                                                          Just waiting on the IRS letter. Katrina is contacting him.
# 42968                                                                                                                                                                                                                                                                                                                   He seems to be sending in everything today. Katrina has been in contact with him.
# 42974                                                                                                                                                                                                                                                                                                                                     Still working with Dottie and getting the chase account set up.
# 42975                                                                                                                                                                                                                                                                                                                        Waiting on their gateway information. But they will get that to dottie soon.
# 42976                                                                                                                                                                                                                                                                                                                                                                          Still working with Dottie.
# 42977                                                                                                                                                                                                                                                                                                                                        Still waiting on them to provide some merchant account info.
# 42982                                                                                                                                                                                                                                                                                                                    Had a great visit at the newman center. They want to set up a demo. Around noon.
# 42989                                                                                                                                                                                                                                                      Said he just got back in from vacation. He will talk with the others this week and said I could follow up on Friday if I didn't hear from him.
# 43003                                                                                                                                                                                                                                                                                                                                                               No one was in the office at the time.
# 43019                                                                                                                                                                                                                                                                                                    i walked her through editing the recurring payment she was trying to edit and she was very happy
# 43039                                                                                                                                                                                                                                                                                                                                            uses networkmerchants.com . the form is a 3 step process
# 43048                                                                                                                                                                                                                                                                                                                                          i got in touch with him and is date of birth is 09/19/1977
# 43057                                                                                                                                                                                                                                                                       She doesn't have any updates today.  They are having a meeting today so we can discuss this a little further later this week.
# 43062                                                                                                                                                                                                                                                                                                                                                                    just got one with fellowship one
# 43077                                                                                                                                                                                                                                                                                                                                           I need to schedule a demo with Tom for tomorrow afternoon
# 43083                                                                                                                                                                                                                                                                                                                                                                       we rescheduled for 3:30pm EST
# 43084                                                                                                                                                                                                                                                                                         comments: Nothing specific at the moment. Would like to get a demonstration of your service & its features.
# 43086                                                                                                                                                                                                                                                                                                                                                                         She is working with Dottie.
# 43094                                                                                                                                                                                                                                                                                                                                                                                 No show for a demo.
# ...                                                                                                                                                                                                                                                                                                                                                                                                   ...
# 43309                                                                                                                                                                                                                                                                                                                                 He has everything in and Jennifer will be talking with him shortly.
# 43310                                                                                                                                                                                                                                                                                                         he is going to the bank today to check on the status. he will send it in as soon as he can.
# 43311                                                                                                                                                                                                                                                                                                                                                                            he asked about QR codes.
# 43321                                                                                                                                                                                                                                                                                                                    Heartland Community Church has completed their information aaron.liford@qgiv.com
# 43328                                                                                                                                                                                                                                                                                                                                                               she is uploading the documents today.
# 43331                                                                                                                                                                                                                                                                                            We can provide them with a invoice during the setup process.  I added the notes into their demo account.
# 43332                                                                                                                                                                                                                                                                                                                                 she wanted to know if we could provide an invoice of the setup fee.
# 43341                                                                                                                                                                                                                                                                                                                I just remembered that they are on spring break and that is why she isn't answering.
# 43350                                                                                                                                                                                                                                                                                                                                                     Jennifer is going to touch base with her today.
# 43354                                                                                                                                                                                                                                                                                            Jen left me a message about setting up the Quickbooks and Salesforce integration on their trial account.
# 43370                                                                                                                                                          Left Bill a message regarding Hobnob and asking if they would entertain the idea of switching event registration systems.  They are currently on active.com as their event is showcased as more of a run event as opposed to a fundraiser.
# 43380                                                                                                                                                                                                                                                                                                                              She is still needing to send in the application and filling documents.
# 43381                                                                                                                                                                                                                                                                                                                                                        Wants us to sell demographic Demo to clients
# 43412                                             I am running in a 5K and collecting donations to help my cousin-in-law raise money for brain cancer surgery he needs in Boston, which the UK will not pay for. I live in California and will be accepting donations from US and overseas. How do I go about setting up an entity that will allow donors to recieve a tax deduction for their donations.
# 43418                                                                                                                                                                                                                                                                                                                                            Said that the new pastor isn't in to that type of stuff.
# 43419                                                                                                                                                                                                The church just found a new pastor.  He is supposed to be in today.  If everyone at the church likes him then he will start on the 31st of March.  She would like for me to follow up with her then.
# 43420                                                          She brought up to the finance committee but hasn't gone any further because they only have a interim pastor.  The new pastor starts in December.  They don't want to make any big changes until he takes over and gets comfortable with his position.  She asked me to follow up after January 1st.  Michelle said, "please don't forget."
# 43457                                                                                                                                                                                                                                                                                                                                               We won't be able to hold the renewal fee for 2 years.
# 43459                                                                                                                        The standard processing volume would have to be $500k to consider giving them a discount.  However, they don't even come close to that.  Sarah sounded somewhat disappointed.  However, they will be researching other products out there and will touch base with me later.
# 43461                                                                                                                                                                                                                                                                                              She will be forwarding me some information in regards to the processing volume for the previous event.
# 43462                                                                                                                                                                  They bring in over a million dollars per year. I need to know how much they raise per event. Based off of that we could offer them a waiver on the renewal fee.  I need to mention that we will throw in the Qgiv product in free.
# 43506                                                                                                                                                                                                                                                                                                                     Bank letter was faxed in yesterday - submitted to GMS with Application for ACH.
# 43521                                                                                                                                                                                                                                                                            she said that Susan would be the one to deal with about setting up a merchant account or tying into the existing account
# 43535                                                                                                                                                                                                                                                                                                                                                        Activated international addresses per Irene.
# 43538  there was a little confusion about a direct integration through Intuit Merchant Services but apparently that was with their donor management system and not Entengo so they are ready to go now with a complete Qgiv setup including the merchant account... we need to update the agreements and let Irene know but once the agreements are updated they will be signing and faxing everything in
# 43556                                                                                                                                                                                                                      she was busy but told me she was looking for something that is free... ha... I told her i would send her the rate card and she could get back with me if she had any questions
# 43563                                                                                                                                                                                                                                                                                                                                                                                  comments: pet name
# 43568                                                                                                                                                                                                                       Said that the BluePay reps will still need some information from them and he is planning on talking with them today. Said that they should be set up by the end of this week.
# 43607                                                                                                                                                                                                                                                                                                                                    Sent Ellen and Joan a Channel Partner Agreement for their review
# 43645                                                                                                                                                                                                                                                            501c3 and 501c19 (military membership). They are real small, very small membership and donations around $6000. Elavaon Merchant account.
#
#        Type
# 42887  None
# 42889  None
# 42899  None
# 42901  None
# 42903  None
# 42921  None
# 42923  None
# 42941  None
# 42942  None
# 42944  None
# 42953  None
# 42967  None
# 42968  None
# 42974  None
# 42975  None
# 42976  None
# 42977  None
# 42982  None
# 42989  None
# 43003  None
# 43019  None
# 43039  None
# 43048  None
# 43057  None
# 43062  None
# 43077  None
# 43083  None
# 43084  None
# 43086  None
# 43094  None
# ...     ...
# 43309  None
# 43310  None
# 43311  None
# 43321  None
# 43328  None
# 43331  None
# 43332  None
# 43341  None
# 43350  None
# 43354  None
# 43370  None
# 43380  None
# 43381  None
# 43412  None
# 43418  None
# 43419  None
# 43420  None
# 43457  None
# 43459  None
# 43461  None
# 43462  None
# 43506  None
# 43521  None
# 43535  None
# 43538  None
# 43556  None
# 43563  None
# 43568  None
# 43607  None
# 43645  None
#
# [100 rows x 3 columns]

# %% [markdown]
# # Storing cleaned & reduced dataset to S3

# %%
cols = ['Id', 'WhoId', 'WhatId', 'Subject', 
        'OwnerId', 'Description', 'Type', 'AccountId', 
        'CreatedDate', 'CreatedById', 'SystemModstamp']
save_dataframe_to_file("sfc-export", "events.clean.csv", df[cols])
# Out:
# uploading to S3
# Done
