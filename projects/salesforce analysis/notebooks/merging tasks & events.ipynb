# %%
import pandas as pd
import sys

sys.path.insert(1, '../../../scripts/')
from s3_support import *

# %%
files = ['tasks.clean.csv', 'events.clean.csv']

df = get_dataframe_from_file("sfc-export", files[0])
df = df.append(get_dataframe_from_file("sfc-export", files[1]))

# %%
df['CreatedDate'] = pd.to_datetime(df['CreatedDate'])
df = df[df['CreatedDate'].dt.year>=2016]

df['Type'] = df['Type'].str.lower()
df['Subject'] = df['Subject'].str.lower()
df['Description'] = df['Description'].str.lower()

# %%
print("{} rows; {} columns".format(len(df), len(df.columns)))
print("\n")

print("Columns:")
print(df.columns)
# Out:
# 459989 rows; 11 columns
#
#
# Columns:
# Index(['Id', 'WhoId', 'WhatId', 'Subject', 'OwnerId', 'Description', 'Type',
#        'AccountId', 'CreatedDate', 'CreatedById', 'SystemModstamp'],
#       dtype='object')

# %%
df['Type'].value_counts(normalize=True)
# Out:
# email                    0.755201
# call                     0.119953
# pre-demo follow up       0.051603
# initial contact          0.027351
# post-demo follow up      0.024622
# demo completed           0.004700
# lead qualification       0.003826
# training                 0.003309
# meeting                  0.002270
# demo scheduled           0.001763
# 60_day_follow_up_call    0.000872
# downgrade                0.000854
# cancellation             0.000648
# upgrade                  0.000630
# one pager campaign       0.000437
# kiosk activity           0.000398
# none                     0.000383
# lead submitted form      0.000317
# mobile vt activity       0.000274
# prepared materials       0.000220
# t-shirt campaign         0.000133
# interested               0.000074
# not interested           0.000054
# recovery                 0.000050
# sale closed              0.000024
# noise                    0.000013
# not ready                0.000009
# webinar                  0.000009
# 60 day follow up         0.000002
# cos - 45 day call        0.000002
# Name: Type, dtype: float64

# %%
type_list = df['Type'].unique().tolist()

# another round of type correction
def infer_type(r):
    for t in type_list:
        if r['Subject'] == t or r['Description'] == t:
            return t
    
    if str(r['Subject']).startswith("email:") and r['Type'] == 'call':
        return 'email'
    if str(r['Description']).startswith('onboarding') or '/onboarding/' in str(r['Subject']):
        return 'onboarding'
    elif str(r['Description']).startswith('training'):
        return 'training'
    elif r['Subject'] == 'phone call' and r['Type'] == 'email':
        return 'call'
    elif 'call with' in str(r['Description']) and r['Type'] == 'email':
        return 'call'
    
    return r['Type']
    
df['Type'] = df.apply(infer_type, axis=1)

# %%
df['Type'].value_counts(normalize=True) * 100.
# Out:
# email                    75.039403
# call                     13.159445
# pre-demo follow up        5.150558
# post-demo follow up       2.458537
# initial contact           2.071789
# demo completed            0.438924
# lead qualification        0.377400
# training                  0.307833
# meeting                   0.155221
# demo scheduled            0.150656
# downgrade                 0.087828
# 60_day_follow_up_call     0.083480
# upgrade                   0.070219
# cancellation              0.068480
# not interested            0.062610
# onboarding                0.060436
# one pager campaign        0.043697
# kiosk activity            0.040218
# cos - 45 day call         0.038914
# lead submitted form       0.031088
# mobile vt activity        0.028044
# none                      0.025435
# prepared materials        0.021957
# t-shirt campaign          0.013261
# interested                0.005218
# recovery                  0.005000
# noise                     0.001304
# sale closed               0.001304
# 60 day follow up          0.000652
# not ready                 0.000652
# webinar                   0.000435
# Name: Type, dtype: float64

# %%
pd.set_option('display.max_colwidth', 500)

df[df['Type']=='email'][['Subject', 'Description']].dropna().iloc[-500:-480]
# Out:
#                                                     Subject  \
# 464054                           email: re: qgiv - auctions
# 464055                           email: re: qgiv - auctions
# 464056                   unresolved email: re: qgiv sign in
# 464058                           email: appointment request
# 464073   email: qgiv for advocates for basic legal equality
# 464074     email: qgiv for st. vincent de paul of baltimore
# 464080                   email: re: women?s resource center
# 464081                   email: re: women?s resource center
# 464092                                email: re: qgiv setup
# 464093                                email: re: qgiv setup
# 464095  email: re: prospective sponsor for apc winter forum
# 464102                   unresolved email: re: qgiv sign in
# 464104                              email: qgiv application
# 464105                              email: qgiv application
# 464116                   email: re: joseph maley foundation
# 464130                           email: fw: qgiv activation
# 464140                              email: qgiv application
# 464144     email: re: qgiv demonstration with barby wolfish
# 464145     email: re: qgiv demonstration with barby wolfish
# 464151                   unresolved email: re: qgiv sign in
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Description
# 464054  additional to: kris.hoxie@bigsupnorth.com cc:  bcc:  attachment:   subject: re: qgiv - auctions body: hi kris,  thank you for providing that information, we do see onecause as one of our closest competitors so it's good to know what they were able to offer that qgiv did not. we will add this information to what need to improve upon.  can i give you a quick call to better understand their system in regards to their live auction features and the check-out process? i would not anticipate this c...
# 464055  additional to: kris.hoxie@bigsupnorth.com cc:  bcc:  attachment:   subject: re: qgiv - auctions body: hi kris,  thank you for providing that information, we do see onecause as one of our closest competitors so it's good to know what they were able to offer that qgiv did not. we will add this information to what need to improve upon.  can i give you a quick call to better understand their system in regards to their live auction features and the check-out process? i would not anticipate this c...
# 464056  additional to: bethcolbyclark@gmail.com cc:  bcc:  attachment: image001.jpg  subject: re: qgiv sign in body: hi beth,  i?ve asked our product team about this and their currently taking a closer look to see what the issue may be. one suggestion was to try logging at https://secure.qgiv.com/control/login with bethclark@stepfunder.com<mailto:bethclark@stepfunder.com> as the username and whatever password you attempted to set last night.  hopefully that will work and you can get in to your demo ...
# 464058  additional to: jwithrow@familypromisebutlercounty.com cc:  bcc:  attachment:   subject: appointment request body: jennifer,  i hope you are doing well.  are you interested in scheduling a live customer-specific gotomeeting webinar to learn more about how qgiv can help you specifically?  my calendly calendar link to schedule a qgiv demonstration.<https://calendly.com/donald-dial/60min>  respectfully;    [http://new.qgiv.com/_resources/images/donald.jpg]  [https://www.g2crowd.com/products/qgiv...
# 464073  additional to: kharshaw@ablelaw.org cc:  bcc:  attachment:   subject: qgiv for advocates for basic legal equality body: good morning karla,  thanks for signing up for our giving tuesday series . i trust you found it to be a valuable resource.  if you've got a few minutes, i'd love to talk to you and learn more about your organization and your online fundraising programs.  it'd be great to hear how you're doing, learn about your fundraising goals, and talk about how qgiv can help you and the ...
# 464074  additional to: dmonaemccloud@gmail.com cc:  bcc:  attachment:   subject: qgiv for st. vincent de paul of baltimore body: good morning darnita,  thanks for downloading our fundraising templates. i trust you found it to be a valuable resource.  if you've got a few minutes, i'd love to talk to you and learn more about your organization and your online fundraising programs.  it'd be great to hear how you're doing, learn about your fundraising goals, and talk about how qgiv can help you and the w...
# 464080  additional to: execdir@tampabay.rr.com cc:  bcc:  attachment: auctions_package.pdf  subject: re: women?s resource center  body: hi cherie,  thank you for going through the demonstration this morning.  attached to this email you will find the handout information that i mentioned.  hopefully this helps.  let me know if any questions come up as you continue your research.  thanks,     [http://new.qgiv.com/_resources/images/aaron.jpg]  [https://www.g2crowd.com/products/qgiv/widgets/stars?color=b...
# 464081  additional to: execdir@tampabay.rr.com cc:  bcc:  attachment: auctions_package.pdf  subject: re: women?s resource center  body: hi cherie,  thank you for going through the demonstration this morning.  attached to this email you will find the handout information that i mentioned.  hopefully this helps.  let me know if any questions come up as you continue your research.  thanks,     [http://new.qgiv.com/_resources/images/aaron.jpg]  [https://www.g2crowd.com/products/qgiv/widgets/stars?color=b...
# 464092  additional to: john.grainger@ocsarts.net cc: afton.lorenz@qgiv.com bcc:  attachment: image001.png, image002.png  subject: re: qgiv setup body: hi john,  i spoke with donor perfect yesterday.  they let me know that they are working on the api credentials for your safe save merchant account.  once they provide that information then we can update the application.  thanks,   thank you,  aaron liford account executive aaron.liford@qgiv.com<mailto:aaron.liford@qgiv.com> 863.496.6121 from: john gra...
# 464093  additional to: john.grainger@ocsarts.net cc: afton.lorenz@qgiv.com bcc:  attachment: image001.png, image002.png  subject: re: qgiv setup body: hi john,  i spoke with donor perfect yesterday.  they let me know that they are working on the api credentials for your safe save merchant account.  once they provide that information then we can update the application.  thanks,   thank you,  aaron liford account executive aaron.liford@qgiv.com<mailto:aaron.liford@qgiv.com> 863.496.6121 from: john gra...
# 464095  additional to: ellen@bristolstrategygroup.com; robing@adgcommunications.com; msbrownllc@att.net cc: rachel.fredrick@qgiv.com bcc:  attachment: image002.png  subject: re: prospective sponsor for apc winter forum body: hi ellen,  thank you so much for the introduction! i apologize for the delayed follow up.  it?s a pleasure to meet you melissa and robin! i?d love to schedule some time to discuss what a sponsorship might look like for 2020 and beyond.  i?m copying rachel fredrick who manages qg...
# 464102  additional to: bethcolbyclark@gmail.com cc:  bcc:  attachment:   subject: re: qgiv sign in body: hi beth,  thanks for confirming!  i tried calling you a few minutes ago but i got your voicemail so i thought i?d respond here.  for security reasons, i don?t think we?re able to set and send you a password. my product team asked me to confirm if you were typing the username in all lower case letters when you were attempting to set your password last night? if you were not, can you go through the...
# 464104  additional to: aumreiko@gmail.com cc:  bcc:  attachment:   subject: qgiv application body: hi andrew,  thank you for choosing qgiv as your fundraising platform!  you should've just received an email from noreply@qgiv.com<mailto:noreply@qgiv.com> prompting you to set a password and begin the application.  there will be a few documents that the merchant processor will request to be uploaded in the application including:  *            copy of the tax exemption determination letter from the irs ...
# 464105  additional to: aumreiko@gmail.com cc:  bcc:  attachment:   subject: qgiv application body: hi andrew,  thank you for choosing qgiv as your fundraising platform!  you should've just received an email from noreply@qgiv.com<mailto:noreply@qgiv.com> prompting you to set a password and begin the application.  there will be a few documents that the merchant processor will request to be uploaded in the application including:  *            copy of the tax exemption determination letter from the irs ...
# 464116  additional to: steven.shattuck@bloomerang.co cc:  bcc:  attachment:   subject: re: joseph maley foundation body: thanks steven!  on an unrelated note, do you have some time to chat next week? i want to discuss the giving institute with you. qgiv has been a member for a couple years now and i thought it might be a good fit for bloomerang too. let me know if you are interested in learning more.  talk soon,   thank you,  brendan smith vp business development brendan.smith@qgiv.com<mailto:brenda...
# 464130  additional to: emailtosalesforce@d9axdy0ycb8wvqkeq4k5fnpl18qvfvjmblr0seifkpl6r4dj5.i-ertgea2.na15.le.salesforce.com cc:  bcc:  attachment: image001.jpg, image002.jpg, image003.jpg  subject: fw: qgiv activation body:      [http://new.qgiv.com/_resources/images/aaron.jpg]  [https://www.g2crowd.com/products/qgiv/widgets/stars?color=blue]<https://www.g2crowd.com/products/qgiv/reviews?utm_source=review-widget>                                 aaron liford account executive 863.496.6121 qgiv donati...
# 464140  additional to: odiesplace508@gmail.com cc:  bcc:  attachment:   subject: qgiv application body: hi brian,  thank you for choosing qgiv as your fundraising platform!  you should've just received an email from noreply@qgiv.com<mailto:noreply@qgiv.com> prompting you to set a password and begin the application.  there will be a few documents that the merchant processor will request to be uploaded in the application including:  *            copy of the tax exemption determination letter from the ...
# 464144  additional to: barby@soidog.org cc:  bcc:  attachment:   subject: re: qgiv demonstration with barby wolfish body: hi barby,  that is correct.  you should've received an email with the log in credentials for go to meeting.  i look forward to speaking with you then.  thanks,     [http://new.qgiv.com/_resources/images/aaron.jpg]  [https://www.g2crowd.com/products/qgiv/widgets/stars?color=blue]<https://www.g2crowd.com/products/qgiv/reviews?utm_source=review-widget>                               ...
# 464145  additional to: barby@soidog.org cc:  bcc:  attachment:   subject: re: qgiv demonstration with barby wolfish body: hi barby,  that is correct.  you should've received an email with the log in credentials for go to meeting.  i look forward to speaking with you then.  thanks,     [http://new.qgiv.com/_resources/images/aaron.jpg]  [https://www.g2crowd.com/products/qgiv/widgets/stars?color=blue]<https://www.g2crowd.com/products/qgiv/reviews?utm_source=review-widget>                               ...
# 464151  additional to: bethcolbyclark@gmail.com cc:  bcc:  attachment:   subject: re: qgiv sign in body: hi beth,  i just resent the activation email. if you follow that process and use your email below in all lower case, you should be able to set your password now. happy to setup a gotomeeting to walk through it with you if you?d like. i?ll be at my desk for another 20minutes or so.  thanks,     [http://new.qgiv.com/_resources/images/brendan.jpg]  [https://www.g2crowd.com/products/qgiv/widgets/star...

# %% [markdown]
# # Store merged data set

# %%
save_dataframe_to_file("sfc-export", "activity_history.csv", df)
# Out:
# uploading to S3
# Done
