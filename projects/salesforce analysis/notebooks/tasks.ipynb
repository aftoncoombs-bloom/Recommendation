# %%
import pandas as pd
import sys

sys.path.insert(1, '../scripts/')
from s3_support import *

# %%
url = get_file_url("sfc-export", "Task.csv")

df = pd.read_csv(url, encoding="ISO-8859-1", low_memory=False)

# %%
drop_cols = ["CallDurationInSeconds", "CallType", "CallDisposition", "CallObject", "RecurrenceActivityId", 
             "IsRecurrence", "RecurrenceStartDateOnly", "RecurrenceEndDateOnly", "RecurrenceTimeZoneSidKey", 
             "RecurrenceType", "RecurrenceInterval", "RecurrenceDayOfWeekMask", "RecurrenceDayOfMonth", 
             "RecurrenceInstance", "RecurrenceMonthOfYear", "RecurrenceRegeneratedType", "bizible2__BizibleId__c", 
             "bizible2__Bizible_Touchpoint_Date__c", "Import2_Id__c", "IsDeleted", "IsArchived"]

df.drop(drop_cols, axis=1, inplace=True)

# %%
print("{} rows".format(len(df)))
print("Columns ({}):".format(len(df.columns)))
print(list(df.columns))
# Out:
# 534469 rows
# Columns (26):
# ['Id', 'WhoId', 'WhatId', 'WhoCount', 'WhatCount', 'Subject', 'ActivityDate', 'Status', 'Priority', 'OwnerId', 'Description', 'Type', 'AccountId', 'IsClosed', 'CreatedDate', 'CreatedById', 'LastModifiedDate', 'LastModifiedById', 'SystemModstamp', 'EmailMessageId', 'ActivityOriginType', 'ReminderDateTime', 'IsReminderSet', 'CompletedDateTime', 'Time_Zone__c', 'Activity_Type__c']

# %%
ids_to_ignore = ["Id", "WhoId", "WhatId", "EmailMessageId", "AccountId"]
group_columns = ["Status", "Priority", "OwnerId", "Type"]
# add CompletedDateTime - CreatedDate to get an approximate duration

df[[c for c in df.columns if c not in ids_to_ignore]].describe()
# Out:
#             WhoCount      WhatCount       IsClosed  ActivityOriginType  \
# count  534469.000000  534469.000000  534469.000000       147384.000000
# mean        0.943914       0.165686       0.993895            2.669951
# std         0.259145       0.371799       0.077896            1.963318
# min         0.000000       0.000000       0.000000            1.000000
# 25%         1.000000       0.000000       1.000000            1.000000
# 50%         1.000000       0.000000       1.000000            1.000000
# 75%         1.000000       0.000000       1.000000            5.000000
# max        22.000000       1.000000       1.000000            5.000000
#
#        IsReminderSet
# count  534469.000000
# mean        0.001820
# std         0.042628
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %%
df['Type'].unique()
# Out:
# array([nan, 'Pre-Demo Follow Up', 'Initial Contact',
#        'Post-Demo Follow Up', 'Web Demo Completed', 'Live Demo Completed',
#        'Demo Scheduled', 'Email', 'Call', 'Lead Qualification',
#        'Conversation', 'Demo/Meeting', '60_Day_Follow_Up_Call',
#        'Phone Call', 'COS - 45 Day Call', 'Training'], dtype=object)

# %%
cols_to_look_at = [c for c in df.columns if c not in ids_to_ignore]

print("looking at columns: {}".format(cols_to_look_at))

df.groupby('Type')[cols_to_look_at].mean().reset_index()
# Out:
# looking at columns: ['WhoCount', 'WhatCount', 'Subject', 'ActivityDate', 'Status', 'Priority', 'OwnerId', 'Description', 'Type', 'IsClosed', 'CreatedDate', 'CreatedById', 'LastModifiedDate', 'LastModifiedById', 'SystemModstamp', 'ActivityOriginType', 'ReminderDateTime', 'IsReminderSet', 'CompletedDateTime', 'Time_Zone__c', 'Activity_Type__c']
#                      Type  WhoCount  WhatCount  IsClosed  ActivityOriginType  \
# 0   60_Day_Follow_Up_Call  0.349127   0.935162  0.900249            5.000000
# 1       COS - 45 Day Call  1.000000   1.000000  0.000000                 NaN
# 2                    Call  0.835058   0.273350  0.984445            4.982759
# 3            Conversation  0.812317   0.371457  0.987292            5.000000
# 4          Demo Scheduled  0.901425   0.750594  0.959620            4.942363
# 5            Demo/Meeting  0.574257   0.787129  0.985149            5.000000
# 6                   Email  0.661006   0.671195  0.977287            3.269294
# 7         Initial Contact  0.879840   0.592123  0.996662            2.172982
# 8      Lead Qualification  0.970455   0.067045  0.993750            4.721739
# 9     Live Demo Completed  0.793103   0.844828  0.982759            5.000000
# 10             Phone Call  1.000000   0.000000  1.000000                 NaN
# 11    Post-Demo Follow Up  0.992918   0.779206  0.983937            3.574899
# 12     Pre-Demo Follow Up  0.996312   0.501379  0.984019            3.901343
# 13               Training  1.000000   0.000000  0.000000                 NaN
# 14     Web Demo Completed  0.932877   0.853784  0.991022            5.000000
#
#     IsReminderSet
# 0        0.002494
# 1        0.000000
# 2        0.008700
# 3        0.008798
# 4        0.005938
# 5        0.009901
# 6        0.009552
# 7        0.000668
# 8        0.003409
# 9        0.017241
# 10       0.000000
# 11       0.003797
# 12       0.010164
# 13       0.000000
# 14       0.005130

# %% [markdown]
# # Cleaning up Task.Type

# %%
print("Is NA: {}".format(len(df[df['Type'].isna()])))
df['Type'].value_counts()
# Out:
# Is NA: 419874
# Call                     54710
# Pre-Demo Follow Up       33352
# Post-Demo Follow Up      13696
# Email                     4711
# Web Demo Completed        2339
# Lead Qualification        1760
# Initial Contact           1498
# Conversation              1023
# Demo Scheduled             842
# 60_Day_Follow_Up_Call      401
# Demo/Meeting               202
# Live Demo Completed         58
# Training                     1
# COS - 45 Day Call            1
# Phone Call                   1
# Name: Type, dtype: int64

# %%
df.groupby('Type')['Status'].value_counts()
# Out:
# Type                   Status
# 60_Day_Follow_Up_Call  Completed        361
#                        Open              40
# COS - 45 Day Call      Open               1
# Call                   Completed      53859
#                        Open             842
#                        Not Started        9
# Conversation           Completed       1010
#                        Open              12
#                        Not Started        1
# Demo Scheduled         Completed        808
#                        Open              34
# Demo/Meeting           Completed        199
#                        Open               3
# Email                  Completed       4604
#                        Open             106
#                        Not Started        1
# Initial Contact        Completed       1493
#                        Open               5
# Lead Qualification     Completed       1749
#                        Open              11
# Live Demo Completed    Completed         57
#                        Open               1
# Phone Call             Completed          1
# Post-Demo Follow Up    Completed      13476
#                        Open             220
# Pre-Demo Follow Up     Completed      32819
#                        Open             531
#                        Not Started        2
# Training               Open               1
# Web Demo Completed     Completed       2318
#                        Open              21
# Name: Status, dtype: int64

# %%
df['Type'] = df['Type'].fillna('None')

def infer_type(r):
    if r['Type'] in ['Web Demo Completed', 'Live Demo Completed', 'Demo/Meeting']:
        return 'Demo Completed'
    elif r['Type'] == 'Phone Call':
        return 'Call'
    elif r['Type'] == 'Conversation':
        return 'Meeting'
    elif r['Type'] == 'None':
        subj = str(r['Subject'])
        
        if 'One-Pager' in subj:
            return 'One Pager Campaign'
        if 'Submitted Form' in subj or 'Contact Us' in subj or 'Received Your Message' in subj or 'Request Web Lead' in subj:
            return 'Lead Submitted Form'
        if 'Thanks for your interest' in subj or 'email' in subj.lower() or 'Qgiv Sign-Up Link' in subj or 'New Customer Inquiry' in subj:
            return 'Email'
        if 'Mobile Field Guide' in subj or 'Autism Nonprofit Boosts Donations'.lower() in subj.lower() or '$10 limit on text giving'.lower() in subj.lower() or 'Level Up' in subj or 'How One Nonprofit Exceed' in subj or 'infographic' in subj.lower() or 'Tips for Managing' in subj or 'eBook'.lower() in subj.lower() or 'Sabotaging Your Peer' in subj or 'Level Up Your Social' in subj or 'Case Study'.lower() in subj.lower() or 'Mobile Fundraising Field ' in subj or 'How Can We Help'.lower() in subj.lower():
            return 'Prepared Materials'
        if 'Are you still interested' in subj or 'Sign-up Reminder' in subj:
            return 'Recovery'
        if 'contact prospect' in subj.lower():
            return 'Initial Contact'
        if 'call' in subj.lower() or 'follow up' in subj.lower().replace('-', ' ') or 'spoke to' in subj.lower():
            return 'Call'
        
        
    return r['Type']

df['Type'] = df.apply(infer_type, axis=1)

# %%
df['Type'].value_counts()
# Out:
# Email                    403295
# Call                      67350
# Pre-Demo Follow Up        33352
# Post-Demo Follow Up       13696
# Prepared Materials         3491
# Demo Completed             2599
# None                       2285
# Lead Qualification         1760
# Lead Submitted Form        1571
# Initial Contact            1568
# One Pager Campaign         1162
# Meeting                    1023
# Demo Scheduled              842
# 60_Day_Follow_Up_Call       401
# Recovery                     72
# Training                      1
# COS - 45 Day Call             1
# Name: Type, dtype: int64

# %%
df[df['Type']=='None'][['Subject', 'Description', 'Type']].tail(50)
# Out:
#                                                   Subject  \
# 510331                               check on application
# 510363                                      respond to vm
# 510385                                         inbound vm
# 510415                                        Web Meeting
# 510424                                  delete short code
# 510434                                  FU if no response
# 510450                               check on application
# 510488                                  In Person Meeting
# 510502                                          Signup FU
# 510517                                         inbound vm
# 510549  ask Brendan if I should create separate opport...
# 510550                               check on application
# 510576                                   Send signup link
# 510578                                   Send signup link
# 510684                                         kiosk demo
# 510686                               check on application
# 510704                               check on application
# 510802                               check on application
# 510851                               check on application
# 510908                               check on application
# 511137                               check on application
# 511138                               check on application
# 511164                               check on application
# 511657                               check on application
# 511874                                       mark as lost
# 511934                                       mark as lost
# 511968                                       mark as lost
# 511976                                         inbound vm
# 512021  figure out who is dealing with their account a...
# 512022                                         inbound vm
# 512084                                   Send signup link
# 512972                                 find out questions
# 513363                                       look to this
# 513700                        check on RE beta time frame
# 513917                                       fix opp name
# 514165                   set up demo with specific set up
# 514767                            setup webmaster contact
# 515862                        get with brendan about this
# 516378                                ask steve questions
# 516971                                 answers from jacob
# 517788                                       mark as lost
# 522925  Opened Preview Message - Rich Text - Church Bo...
# 522926  Opened Preview Message - Rich Text - Church Bo...
# 522927  Sent Preview Message - Rich Text - Church Boos...
# 522929  Opened Preview Message - Rich Text - Church Bo...
# 522930  Opened Preview Message - Rich Text - Church Bo...
# 522931  Sent Preview Message - Rich Text - Church Boos...
# 525966  Opened Preview Message - Rich Text - Message R...
# 525967  Sent Preview Message - Rich Text - Message Rec...
# 528387                              Sent New Info Request
#
#                                               Description  Type
# 510331                                                NaN  None
# 510363                                                NaN  None
# 510385  left a message curious to hear what I have to ...  None
# 510415  He was very happy with the Hobnob Demonstratio...  None
# 510424                                                NaN  None
# 510434  Regarding larger corporate entity Sisters of C...  None
# 510450                                                NaN  None
# 510488  They are really excited about the text giving ...  None
# 510502                                    If no repsonse.  None
# 510517  Left a vm stating that he is interested in tex...  None
# 510549                                                NaN  None
# 510550                                                NaN  None
# 510576                                                NaN  None
# 510578                                                NaN  None
# 510684  The kiosk demo went really well.  Sharon sound...  None
# 510686                                                NaN  None
# 510704                                                NaN  None
# 510802                                                NaN  None
# 510851                                                NaN  None
# 510908                                                NaN  None
# 511137                                                NaN  None
# 511138                                                NaN  None
# 511164                                                NaN  None
# 511657                                                NaN  None
# 511874                                                NaN  None
# 511934                                                NaN  None
# 511968                                                NaN  None
# 511976  returned my call.  said that her phone was on ...  None
# 512021  Jennifer is looking into this and will follow ...  None
# 512022  Denise has called in stating that she has call...  None
# 512084                                                NaN  None
# 512972  Jennifer stated that they can switch there mer...  None
# 513363                                                NaN  None
# 513700                                                NaN  None
# 513917                                                NaN  None
# 514165                                                NaN  None
# 514767                                                NaN  None
# 515862  Brendan stated that he emailed her and haven't...  None
# 516378  No, and no. Only when we create a new account ...  None
# 516971  *  We don't have a iframe tutorial.  *  parts ...  None
# 517788                                                NaN  None
# 522925                                                NaN  None
# 522926                                                NaN  None
# 522927                                                NaN  None
# 522929                                                NaN  None
# 522930                                                NaN  None
# 522931                                                NaN  None
# 525966                                                NaN  None
# 525967                                                NaN  None
# 528387                                                NaN  None

# %%
df['Status'].value_counts()
# Out:
# Completed      531206
# Open             3250
# Not Started        13
# Name: Status, dtype: int64

# %%
cols = ['Id', 'WhoId', 'WhatId', 'Subject', 
        'OwnerId', 'Description', 'Type', 'AccountId', 
        'CreatedDate', 'CreatedById', 'SystemModstamp']
save_dataframe_to_file("sfc-export", "tasks.clean.csv", df[cols])
# Out:
# uploading to S3
# Done
