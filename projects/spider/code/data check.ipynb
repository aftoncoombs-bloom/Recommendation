# %%
import pandas as pd

# %%
df = pd.read_csv("org_website_data.csv")

# %%
df['date'].unique()
# Out:
# array(['2020-06-02', '2020-06-15'], dtype=object)

# %%
df.groupby('date')['date'].count()
# Out:
# date
# 2020-06-02    40128
# 2020-06-15     2712
# Name: date, dtype: int64
