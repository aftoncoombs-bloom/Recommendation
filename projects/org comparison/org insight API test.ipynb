# %%
import pandas as pd
import numpy as np

import sys, requests
sys.path.insert(1, '../../scripts/')
from s3_support import *

# %%
URL = 'https://orginsights.qgiv.com/orginsights/'
API_KEY = 'tIHLM2vNlBwvlZlqdKy8'

# %%
p = {}
r = requests.post(URL, data=p, verify=False)
r.text
# Out:
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1020: InsecureRequestWarning: Unverified HTTPS request is being made to host 'orginsights.qgiv.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# '{\n  "errors": "Incorrect input",\n  "success": "0"\n}\n'

# %%
p = {'key': API_KEY}
r = requests.post(URL, data=p, verify=False)
r.text
# Out:
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1020: InsecureRequestWarning: Unverified HTTPS request is being made to host 'orginsights.qgiv.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# '{\n  "error": "Error attempting to calculate insight; \'insights\'",\n  "success": 0\n}\n'

# %%
p = {
    'insights': 'contribution_total,average_contribution_amount',
    'timeframe': '3months',
    'segment': 'youth',
    'key': API_KEY
}
    
r = requests.post(URL, data=p, verify=False)
r.text
# Out:
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1020: InsecureRequestWarning: Unverified HTTPS request is being made to host 'orginsights.qgiv.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# '{\n  "stats": [\n    {\n      "insight": "contribution_total",\n      "stat": "16882.5933992095"\n    },\n    {\n      "insight": "average_contribution_amount",\n      "stat": "143.59228568547"\n    }\n  ],\n  "success": 1\n}\n'
