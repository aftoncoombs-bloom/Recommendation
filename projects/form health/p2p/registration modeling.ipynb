# %%
import pandas as pd
import numpy as np
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("~/Repositories/datasets/analytics_p2p_registrations.csv")

# %%
drop_cols = ['product', 'sms_trans_vol', 'p2p_trans_vol', 'kiosk_trans_vol', 
             'fb_trans_count', 'sms_trans_count', 'kiosk_trans_count', 'p2p_trans_count', 
             'mobile_visits', 'vt_trans_count', 'vt_trans_vol', 'don_form_trans_count', 
             'don_form_trans_vol', 'form', 'org', 'id', 'fb_trans_vol', 
             'one_time_trans_count', 'one_time_trans_vol', 'rec_trans_count', 
             'rec_trans_vol', 'mobile_trans_count', 'mobile_trans_vol', 
             'mobilevt_trans_count', 'mobilevt_trans_vol', 'reg_volume', 'don_volume', 'don_count']
df = df.drop(drop_cols, axis=1)

# %%
df['reg_conversion'] = df['reg_count']/df['visits']
df.columns
# Out:
# Index([u'Unnamed: 0', u'sic', u'ein', u'visits', u'tm_stamp', u'class_count',
#        u'cat_count', u'promo_count', u'rest_count', u'amt_count', u'ded_count',
#        u'fields', u'opt_fields', u'req_fields', u'allows_reg_ind',
#        u'allows_teams', u'allows_reg_team_create', u'allows_reg_team_join',
#        u'allows_opt_reg_donation', u'allows_sub_reg', u'allows_sub_reg_pfp',
#        u'allows_other_don_amt', u'allows_pfp_off_don', u'allows_tfp_off_don',
#        u'allows_soc_post_pfp_tcp', u'share_home', u'share_pfp', u'share_tfp',
#        u'share_therm', u'share_donation', u'allows_social',
#        u'social_templt_count', u'social_auto', u'pcnt_posts', u'mon_posts',
#        u'count_posts', u'date_posts', u'email_templt_count', u'sponsors_count',
#        u'inappr_content', u'reg_count', u'non_fund_reg', u'sub_reg_count',
#        u'teams_count', u'reg_amt', u'reg_conversion'],
#       dtype='object')

# %%
print("Target variable characteristics:")
print("\tRegistration Count:")
print("\t\tmean: {}".format(df.reg_count.mean()))
print("\t\tstd: {}".format(df.reg_count.std()))
print("\tRegistration Amount:")
print("\t\tmean: {}".format(df.reg_amt.mean()))
print("\t\tstd: {}".format(df.reg_amt.std()))
print("\tRegistration Conversion:")
print("\t\tmean: {}".format(df.reg_conversion.mean()))
print("\t\tstd: {}".format(df.reg_conversion.std()))
# Out:
# Target variable characteristics:
# 	Registration Count:
# 		mean: 0.370938022201
# 		std: 2.76980622132
# 	Registration Amount:
# 		mean: 3.8912518277
# 		std: 46.411891162
# 	Registration Conversion:
# 		mean: 0.162489781408
# 		std: 1.49476779465

# %%
ftrs = ['class_count', 'cat_count', 'promo_count', 'rest_count', 'fields', 
        'opt_fields', 'req_fields', 'allows_reg_ind', 'allows_teams', 'allows_reg_team_create',
       'allows_reg_team_join', 'allows_opt_reg_donation', 'allows_sub_reg', 'allows_sub_reg_pfp',
       'share_home', 'share_pfp', 'share_tfp', 'share_therm', 'share_donation', 'allows_social',
       'teams_count', 'reg_count', 'reg_amt', 'reg_conversion']
df_ftrs = df[ftrs]

# %% [markdown]
# # Random Forest modeling

# %%
mse = []
exv = []
r2 = []
for i in range(10):
    X_train, X_test, y_train, y_test = train_test_split(df_ftrs.drop(['reg_count', 'reg_amt'], axis=1), df_ftrs['reg_count'], test_size=0.25)
    rf = RandomForestRegressor(n_estimators=100)
    rf.fit(X_train, y_train)
    y_pred = rf.predict(X_test)
    mse.append(metrics.mean_squared_error(y_test, y_pred))
    exv.append(metrics.explained_variance_score(y_test, y_pred))
    r2.append(metrics.r2_score(y_test, y_pred))
print("RF w/ 100 trees:")
print("\tMSE: {}".format(np.mean(mse)))
print("\tExplained variance: {}".format(np.mean(exv)))
print("\tR^2: {}".format(np.mean(r2)))
# Out:
# RF w/ 100 trees:
# 	MSE: 8.28362236356
# 	Explained variance: -0.00229567213532
# 	R^2: -0.00231163238649

# %%
for i in range(len(X_test.columns)):
    print("{}: {}".format(X_test.columns[i], rf.feature_importances_[i]))
# Out:
# class_count: 0.175738004739
# cat_count: 0.161261378846
# promo_count: 0.161510568316
# rest_count: 0.0118656674375
# fields: 0.0969075601821
# opt_fields: 0.0403493466081
# req_fields: 0.0471703863334
# allows_reg_ind: 0.0290808182716
# allows_teams: 0.0108356534603
# allows_reg_team_create: 0.00889787591117
# allows_reg_team_join: 0.0105201364162
# allows_opt_reg_donation: 0.030901570135
# allows_sub_reg: 1.4627277453e-06
# allows_sub_reg_pfp: 0.000872150081081
# share_home: 0.0
# share_pfp: 0.0
# share_tfp: 0.0
# share_therm: 0.0
# share_donation: 0.0
# allows_social: 0.00101219520463
# teams_count: 0.21307522533

# %% [markdown]
# # GBR modeling

# %%
mse = []
exv = []
r2 = []
for i in range(10):
    X_train, X_test, y_train, y_test = train_test_split(df_ftrs.drop(['reg_count', 'reg_amt'], axis=1), df_ftrs['reg_count'], test_size=0.25)
    gbr = GradientBoostingRegressor(n_estimators=100)
    gbr.fit(X_train, y_train)
    y_pred = gbr.predict(X_test)
    mse.append(metrics.mean_squared_error(y_test, y_pred))
    exv.append(metrics.explained_variance_score(y_test, y_pred))
    r2.append(metrics.r2_score(y_test, y_pred))
print("RF w/ 100 trees:")
print("\tMSE: {}".format(np.mean(mse)))
print("\tExplained variance: {}".format(np.mean(exv)))
print("\tR^2: {}".format(np.mean(r2)))
# Out:
# RF w/ 100 trees:
# 	MSE: 9.21816128196
# 	Explained variance: 8.42651662704e-05
# 	R^2: 5.26522176548e-05

# %% [markdown]
# # Random Forest modeling of registration conversion

# %%
mse = []
exv = []
r2 = []
for i in range(10):
    X_train, X_test, y_train, y_test = train_test_split(df_ftrs.drop(['reg_count', 'reg_amt', 'reg_conversion'], axis=1), df_ftrs['reg_conversion'], test_size=0.25)
    rf = RandomForestRegressor(n_estimators=100)
    rf.fit(X_train, y_train)
    y_pred = rf.predict(X_test)
    mse.append(metrics.mean_squared_error(y_test, y_pred))
    exv.append(metrics.explained_variance_score(y_test, y_pred))
    r2.append(metrics.r2_score(y_test, y_pred))
print("RF w/ 100 trees against registration conversion:")
print("\tMSE: {}".format(np.mean(mse)))
print("\tExplained variance: {}".format(np.mean(exv)))
print("\tR^2: {}".format(np.mean(r2)))
# Out:
# RF w/ 100 trees against registration conversion:
# 	MSE: 1.7350273127
# 	Explained variance: 0.000434554329489
# 	R^2: 0.000389561139766

# %% [markdown]
# # Modeling different feature sets
#
# Dropping all binary setting features (allows_*) and adding sponsors count to see if results differ notably.

# %%
ftrs = ['sponsors_count', 'class_count', 'cat_count', 'promo_count', 'rest_count', 'fields', 
        'opt_fields', 'req_fields', 'teams_count', 'reg_count', 'reg_amt', 'reg_conversion']
df_ftrs = df[ftrs]

# %% [markdown]
# ## Random Forest modeling registration conversion w/ some feature selection

# %%
mse = []
exv = []
r2 = []
for i in range(10):
    X_train, X_test, y_train, y_test = train_test_split(df_ftrs.drop(['reg_count', 'reg_amt', 'reg_conversion'], axis=1), df_ftrs['reg_conversion'], test_size=0.25)
    rf = RandomForestRegressor(n_estimators=100)
    rf.fit(X_train, y_train)
    y_pred = rf.predict(X_test)
    mse.append(metrics.mean_squared_error(y_test, y_pred))
    exv.append(metrics.explained_variance_score(y_test, y_pred))
    r2.append(metrics.r2_score(y_test, y_pred))
print("RF w/ 100 trees against registration conversion:")
print("\tMSE: {}".format(np.mean(mse)))
print("\tExplained variance: {}".format(np.mean(exv)))
print("\tR^2: {}".format(np.mean(r2)))
# Out:
# RF w/ 100 trees against registration conversion:
# 	MSE: 2.53004399463
# 	Explained variance: 0.000683080475513
# 	R^2: 0.000660716413522

# %% [markdown]
# So this performed worse than the original feature set, so there you go.

# %% [markdown]
# Trying the original feature set + sponsors count.

# %%
ftrs = ['class_count', 'cat_count', 'promo_count', 'rest_count', 'fields', 
        'opt_fields', 'req_fields', 'allows_reg_ind', 'allows_teams', 'allows_reg_team_create',
       'allows_reg_team_join', 'allows_opt_reg_donation', 'allows_sub_reg', 'allows_sub_reg_pfp',
       'share_home', 'share_pfp', 'share_tfp', 'share_therm', 'share_donation', 'allows_social',
       'teams_count', 'reg_count', 'reg_amt', 'reg_conversion', 'sponsors_count']
df_ftrs = df[ftrs]

# %%
mse = []
exv = []
r2 = []
for i in range(10):
    X_train, X_test, y_train, y_test = train_test_split(df_ftrs.drop(['reg_count', 'reg_amt', 'reg_conversion'], axis=1), df_ftrs['reg_conversion'], test_size=0.25)
    rf = RandomForestRegressor(n_estimators=100)
    rf.fit(X_train, y_train)
    y_pred = rf.predict(X_test)
    mse.append(metrics.mean_squared_error(y_test, y_pred))
    exv.append(metrics.explained_variance_score(y_test, y_pred))
    r2.append(metrics.r2_score(y_test, y_pred))
print("RF w/ 100 trees against registration conversion:")
print("\tMSE: {}".format(np.mean(mse)))
print("\tExplained variance: {}".format(np.mean(exv)))
print("\tR^2: {}".format(np.mean(r2)))
# Out:
# RF w/ 100 trees against registration conversion:
# 	MSE: 2.52451839273
# 	Explained variance: 0.000707498826208
# 	R^2: 0.000683219449899

# %% [markdown]
# Still notably worse than the original feature set. Clearly sponsors count is dragging the model down. Now let's try some backward stepwise feature selection against the original random forest model, original feature set, and see if we can't find anything more accurate or efficient.

# %%
for y in ['reg_count', 'reg_amt', 'reg_conversion']:
    print("Modeling against {}".format(y))
    mse = []
    exv = []
    r2 = []
    for i in range(10):
        X_train, X_test, y_train, y_test = train_test_split(df_ftrs.drop(['reg_count', 'reg_amt', 'reg_conversion'], axis=1), df_ftrs[y], test_size=0.25)
        rf = RandomForestRegressor(n_estimators=100)
        rf.fit(X_train, y_train)
        y_pred = rf.predict(X_test)
        mse.append(metrics.mean_squared_error(y_test, y_pred))
        exv.append(metrics.explained_variance_score(y_test, y_pred))
        r2.append(metrics.r2_score(y_test, y_pred))
    print("Base:")
    print("\tMSE: {}; variance explained: {}; r^2: {}".format(np.mean(mse), np.mean(exv), np.mean(r2)))

    dropped_metrics = {}
    for c in X_test.columns:
        mse = []
        exv = []
        r2 = []
        for i in range(10):
            X_train, X_test, y_train, y_test = train_test_split(df_ftrs.drop([c, 'reg_count', 'reg_amt', 'reg_conversion'], axis=1), df_ftrs[y], test_size=0.25)
            rf = RandomForestRegressor(n_estimators=100)
            rf.fit(X_train, y_train)
            y_pred = rf.predict(X_test)
            mse.append(metrics.mean_squared_error(y_test, y_pred))
            exv.append(metrics.explained_variance_score(y_test, y_pred))
            r2.append(metrics.r2_score(y_test, y_pred))
        print("Dropping {}:".format(c))
        print("\tMSE: {}; variance explained: {}; r^2: {}".format(np.mean(mse), np.mean(exv), np.mean(r2)))
        dropped_metrics[c] = {'mse': np.mean(mse), 'exv': np.mean(exv), 'r2': np.mean(r2)}
# Out:
# Modeling against reg_count
# Base:
# 	MSE: 6.94991847449; variance explained: -0.00301030505204; r^2: -0.00301758947524
# Dropping class_count:
# 	MSE: 7.56037292026; variance explained: -0.00181223442934; r^2: -0.00183441777741
# Dropping cat_count:
# 	MSE: 7.54230862449; variance explained: -0.00257750303874; r^2: -0.00261176844221
# Dropping promo_count:
# 	MSE: 6.85983089404; variance explained: -0.00319833358729; r^2: -0.00322776374637
# Dropping rest_count:
# 	MSE: 7.25724724551; variance explained: -0.00232950789838; r^2: -0.00233731679647
# Dropping fields:
# 	MSE: 9.19342738314; variance explained: -0.00263497467291; r^2: -0.00265925473631
# Dropping opt_fields:
# 	MSE: 7.97173356645; variance explained: -0.00213623226474; r^2: -0.0021593096542
# Dropping req_fields:
# 	MSE: 6.66111176494; variance explained: -0.00320425178996; r^2: -0.00321876428381
# Dropping allows_reg_ind:
# 	MSE: 7.54170511101; variance explained: -0.00291855779953; r^2: -0.0029650419123
# Dropping allows_teams:
# 	MSE: 8.22640369677; variance explained: -0.00232351871037; r^2: -0.00234403576358
# Dropping allows_reg_team_create:
# 	MSE: 7.60671510474; variance explained: -0.0027688765017; r^2: -0.00279946497635
# Dropping allows_reg_team_join:
# 	MSE: 8.08026758849; variance explained: -0.00197776584047; r^2: -0.00198836148222
# Dropping allows_opt_reg_donation:
# 	MSE: 7.150602371; variance explained: -0.00288699848066; r^2: -0.00289697345857
# Dropping allows_sub_reg:
# 	MSE: 7.27979409078; variance explained: -0.00255697800508; r^2: -0.00257524271518
# Dropping allows_sub_reg_pfp:
# 	MSE: 8.12314575793; variance explained: -0.00276756309689; r^2: -0.00278901172599
# Dropping share_home:
# 	MSE: 8.92830237338; variance explained: -0.00232523589455; r^2: -0.00235732279356
# Dropping share_pfp:
# 	MSE: 7.07744961932; variance explained: -0.00324407503564; r^2: -0.00327307040078
# Dropping share_tfp:
# 	MSE: 8.01354481933; variance explained: -0.00231951850467; r^2: -0.00234490591629
# Dropping share_therm:
# 	MSE: 6.56458570413; variance explained: -0.00325968382869; r^2: -0.00327944233912
# Dropping share_donation:
# 	MSE: 7.47075740423; variance explained: -0.00307181057432; r^2: -0.00310746082537
# Dropping allows_social:
# 	MSE: 7.18874689101; variance explained: -0.00364758669845; r^2: -0.00366299816897
# Dropping teams_count:
# 	MSE: 7.93921691454; variance explained: -0.00063982448987; r^2: -0.000661629784201
# Modeling against reg_amt
# Base:
# 	MSE: 2227.32263889; variance explained: -0.0125328461343; r^2: -0.0125608689979
# Dropping class_count:
# 	MSE: 1795.8573544; variance explained: -0.0106741638399; r^2: -0.010695173947
# Dropping cat_count:
# 	MSE: 1912.77332232; variance explained: -0.00981182015057; r^2: -0.0098593296955
# Dropping promo_count:
# 	MSE: 1884.85464361; variance explained: -0.00972431006382; r^2: -0.00975146824927
# Dropping rest_count:
# 	MSE: 2275.38541989; variance explained: -0.00988253801614; r^2: -0.00989313021017
# Dropping fields:
# 	MSE: 2151.58041084; variance explained: -0.012330476213; r^2: -0.0123605103499
# Dropping opt_fields:
# 	MSE: 1732.45297657; variance explained: -0.0146190729795; r^2: -0.0146581384409
# Dropping req_fields:
# 	MSE: 2236.10878181; variance explained: -0.00985414071451; r^2: -0.00987542787547
# Dropping allows_reg_ind:
# 	MSE: 1669.10856011; variance explained: -0.0139381706034; r^2: -0.0139758849449
# Dropping allows_teams:
# 	MSE: 2048.98243399; variance explained: -0.0110929114647; r^2: -0.011105804419
# Dropping allows_reg_team_create:
# 	MSE: 2461.88088559; variance explained: -0.0078599390897; r^2: -0.0078741289766
# Dropping allows_reg_team_join:
# 	MSE: 1904.21430396; variance explained: -0.0130034913773; r^2: -0.0130420754306
# Dropping allows_opt_reg_donation:
# 	MSE: 1981.00662363; variance explained: -0.0106534361712; r^2: -0.0106748682407
# Dropping allows_sub_reg:
# 	MSE: 2181.35100163; variance explained: -0.0105753766743; r^2: -0.0106120453032
# Dropping allows_sub_reg_pfp:
# 	MSE: 2294.10464423; variance explained: -0.00943539287158; r^2: -0.00944238170566
# Dropping share_home:
# 	MSE: 2283.03011888; variance explained: -0.0111109033739; r^2: -0.0111378122607
# Dropping share_pfp:
# 	MSE: 2013.90578388; variance explained: -0.0120277871631; r^2: -0.0120516709062
# Dropping share_tfp:
# 	MSE: 2125.04356273; variance explained: -0.010512627083; r^2: -0.0105332409182
# Dropping share_therm:
# 	MSE: 2213.85779791; variance explained: -0.0103358030172; r^2: -0.0103534813142
# Dropping share_donation:
# 	MSE: 1963.75200711; variance explained: -0.0117823574454; r^2: -0.0117902855435
# Dropping allows_social:
# 	MSE: 1745.88488117; variance explained: -0.011738058777; r^2: -0.011764360708
# Dropping teams_count:
# 	MSE: 2228.58961223; variance explained: -0.0058234858192; r^2: -0.00583552363227
# Modeling against reg_conversion
# Base:
# 	MSE: 2.24616813442; variance explained: 0.000631967706846; r^2: 0.00061959221893
# Dropping class_count:
# 	MSE: 2.0980321694; variance explained: 0.000473461138279; r^2: 0.000450700234497
# Dropping cat_count:
# 	MSE: 1.83640606713; variance explained: 0.00100523807652; r^2: 0.000988666118309
# Dropping promo_count:
# 	MSE: 2.07183817029; variance explained: 0.00102763833391; r^2: 0.00100946344188
# Dropping rest_count:
# 	MSE: 1.75052105584; variance explained: 0.000727115955976; r^2: 0.000709157858457
# Dropping fields:
# 	MSE: 2.4773014333; variance explained: 0.000589733180047; r^2: 0.000565603755201
# Dropping opt_fields:
# 	MSE: 1.78664244531; variance explained: 0.000585552874673; r^2: 0.000568982234264
# Dropping req_fields:
# 	MSE: 2.06951822921; variance explained: 0.00078595791292; r^2: 0.000762959634931
# Dropping allows_reg_ind:
# 	MSE: 2.01091388565; variance explained: 0.000459708794989; r^2: 0.000441034389128
# Dropping allows_teams:
# 	MSE: 2.36498387472; variance explained: 0.000365480964369; r^2: 0.000342435750876
# Dropping allows_reg_team_create:
# 	MSE: 2.64437509948; variance explained: 0.000855546566483; r^2: 0.00084369790195
# Dropping allows_reg_team_join:
# 	MSE: 2.58323274962; variance explained: 0.000331731947993; r^2: 0.000311721189361
# Dropping allows_opt_reg_donation:
# 	MSE: 1.90319747139; variance explained: 0.000478960827235; r^2: 0.000463973661705
# Dropping allows_sub_reg:
# 	MSE: 2.04857123728; variance explained: 0.000596061971714; r^2: 0.000573183564335
# Dropping allows_sub_reg_pfp:
# 	MSE: 2.52715370731; variance explained: 0.000278943648844; r^2: 0.000262622456751
# Dropping share_home:
# 	MSE: 2.41773647905; variance explained: 0.000693964192271; r^2: 0.000666320611237
# Dropping share_pfp:
# 	MSE: 2.13744855998; variance explained: 0.000365451182698; r^2: 0.000353589090778
# Dropping share_tfp:
# 	MSE: 2.58545040923; variance explained: 0.000394241995417; r^2: 0.000375814568587

# %% [markdown]
# Dropping fields significantly improved accuracy, but not the variance explained or $r^2$

# %%
print("Modeling against {}".format('reg_conversion'))
mse = []
exv = []
r2 = []

for i in range(20):
    X_train, X_test, y_train, y_test = train_test_split(df_ftrs.drop(['reg_count', 'reg_amt', 'reg_conversion'], axis=1), df_ftrs['reg_conversion'], test_size=0.25)
    rf = RandomForestRegressor(n_estimators=100)
    rf.fit(X_train, y_train)
    y_pred = rf.predict(X_test)
    mse.append(metrics.mean_squared_error(y_test, y_pred))
    exv.append(metrics.explained_variance_score(y_test, y_pred))
    r2.append(metrics.r2_score(y_test, y_pred))
print("Base:")
print("\tMSE: {}; variance explained: {}; r^2: {}".format(np.mean(mse), np.mean(exv), np.mean(r2)))

from itertools import chain, combinations

dropped_metrics = {}
feature_list = ['allows_reg_team_create', 'req_fields', 'fields', 'opt_fields', 'rest_count', 'share_home']
drop_feature_lists = chain.from_iterable(combinations(feature_list,n) for n in range(len(feature_list)+1))
for c in drop_feature_lists:
    if len(c) > 0:
        mse = []
        exv = []
        r2 = []
        for i in range(20):
            X_train, X_test, y_train, y_test = train_test_split(df_ftrs.drop(['reg_count', 'reg_amt', 'reg_conversion'], axis=1).drop(list(c), axis=1), df_ftrs['reg_conversion'], test_size=0.25)
            rf = RandomForestRegressor(n_estimators=100)
            rf.fit(X_train, y_train)
            y_pred = rf.predict(X_test)
            mse.append(metrics.mean_squared_error(y_test, y_pred))
            exv.append(metrics.explained_variance_score(y_test, y_pred))
            r2.append(metrics.r2_score(y_test, y_pred))
        print("Dropping {}:".format(c))
        print("\tMSE: {}; variance explained: {}; r^2: {}".format(np.mean(mse), np.mean(exv), np.mean(r2)))
        dropped_metrics[c] = {'mse': np.mean(mse), 'exv': np.mean(exv), 'r2': np.mean(r2)}
# Out:
# Modeling against reg_conversion
# Base:
# 	MSE: 2.16182789706; variance explained: 0.00108410206803; r^2: 0.001059420598
# Dropping ('allows_reg_team_create',):
# 	MSE: 2.06040585798; variance explained: 0.00039309129375; r^2: 0.000371853220205
# Dropping ('req_fields',):
# 	MSE: 2.21490390637; variance explained: 0.000801581496315; r^2: 0.000788423441736
# Dropping ('fields',):
# 	MSE: 2.419462945; variance explained: 0.000749546732996; r^2: 0.000725784201399
# Dropping ('opt_fields',):
# 	MSE: 2.48332616884; variance explained: 0.0008303929663; r^2: 0.000814899633683
# Dropping ('rest_count',):
# 	MSE: 2.29901520311; variance explained: 0.000663722792234; r^2: 0.000652213906218
# Dropping ('share_home',):
# 	MSE: 2.0666510956; variance explained: 0.000730240222839; r^2: 0.000703350370759
# Dropping ('allows_reg_team_create', 'req_fields'):
# 	MSE: 2.16155519209; variance explained: 0.000682762208875; r^2: 0.000658573326496
# Dropping ('allows_reg_team_create', 'fields'):
# 	MSE: 1.94594357679; variance explained: 0.000572421875912; r^2: 0.000548622291482
# Dropping ('allows_reg_team_create', 'opt_fields'):
# 	MSE: 2.3983468455; variance explained: 0.000695444228541; r^2: 0.000682985473653
# Dropping ('allows_reg_team_create', 'rest_count'):
# 	MSE: 2.48995738144; variance explained: 0.000300825229332; r^2: 0.000278964168954
# Dropping ('allows_reg_team_create', 'share_home'):
# 	MSE: 2.67245269952; variance explained: 0.000532480616974; r^2: 0.000517498507919
# Dropping ('req_fields', 'fields'):
# 	MSE: 2.2532800399; variance explained: 0.000880711270473; r^2: 0.000855307287977
# Dropping ('req_fields', 'opt_fields'):
# 	MSE: 1.99581056248; variance explained: 0.000888967831156; r^2: 0.000856973071853
# Dropping ('req_fields', 'rest_count'):
# 	MSE: 2.12638579139; variance explained: 0.000803115294718; r^2: 0.000773637786828
# Dropping ('req_fields', 'share_home'):
# 	MSE: 1.7705980284; variance explained: 0.000569758904065; r^2: 0.000559678700165
# Dropping ('fields', 'opt_fields'):
# 	MSE: 2.0486804642; variance explained: 0.000789763850797; r^2: 0.000782425263032
# Dropping ('fields', 'rest_count'):
# 	MSE: 2.61823451174; variance explained: 0.000620085888471; r^2: 0.000601569617933
# Dropping ('fields', 'share_home'):
# 	MSE: 2.36866421502; variance explained: 0.000269165403637; r^2: 0.00025878278773
# Dropping ('opt_fields', 'rest_count'):
# 	MSE: 2.35384918331; variance explained: 0.000442304985705; r^2: 0.000427295540009
# Dropping ('opt_fields', 'share_home'):
# 	MSE: 2.16091038173; variance explained: 0.000656558712626; r^2: 0.000645297656962
# Dropping ('rest_count', 'share_home'):
# 	MSE: 2.70489958251; variance explained: 0.000757854983638; r^2: 0.000745863703546
# Dropping ('allows_reg_team_create', 'req_fields', 'fields'):
# 	MSE: 2.51473213105; variance explained: 0.0007334810895; r^2: 0.000707827852579
# Dropping ('allows_reg_team_create', 'req_fields', 'opt_fields'):
# 	MSE: 1.96244504404; variance explained: 0.000674674246668; r^2: 0.000659592313226
# Dropping ('allows_reg_team_create', 'req_fields', 'rest_count'):
# 	MSE: 2.09931037272; variance explained: 0.000519455090159; r^2: 0.000505268132351
# Dropping ('allows_reg_team_create', 'req_fields', 'share_home'):
# 	MSE: 2.1739029168; variance explained: 0.000489585377122; r^2: 0.000465587132123
# Dropping ('allows_reg_team_create', 'fields', 'opt_fields'):
# 	MSE: 1.86746345955; variance explained: 0.000822191283294; r^2: 0.000791419559986
# Dropping ('allows_reg_team_create', 'fields', 'rest_count'):
# 	MSE: 2.26545248383; variance explained: 0.000596117012466; r^2: 0.000584928658067
# Dropping ('allows_reg_team_create', 'fields', 'share_home'):
# 	MSE: 2.069470968; variance explained: 0.000644320598148; r^2: 0.000630559339289
# Dropping ('allows_reg_team_create', 'opt_fields', 'rest_count'):
# 	MSE: 2.4646781589; variance explained: 0.000412216982594; r^2: 0.00040098419177
# Dropping ('allows_reg_team_create', 'opt_fields', 'share_home'):
# 	MSE: 2.14879015408; variance explained: 0.000537575345057; r^2: 0.000470101658922
# Dropping ('allows_reg_team_create', 'rest_count', 'share_home'):
# 	MSE: 2.2194988856; variance explained: 0.000844760243963; r^2: 0.000835545658659
# Dropping ('req_fields', 'fields', 'opt_fields'):
# 	MSE: 2.0783326628; variance explained: 0.00120810686587; r^2: 0.00119014401377
# Dropping ('req_fields', 'fields', 'rest_count'):
# 	MSE: 2.31716691867; variance explained: 0.00100075215206; r^2: 0.000982050647119
# Dropping ('req_fields', 'fields', 'share_home'):
# 	MSE: 2.53572894048; variance explained: 0.000836971204215; r^2: 0.000826798661141
# Dropping ('req_fields', 'opt_fields', 'rest_count'):
# 	MSE: 2.49106938225; variance explained: 0.000701008133295; r^2: 0.000678142231609
# Dropping ('req_fields', 'opt_fields', 'share_home'):
# 	MSE: 1.99086352479; variance explained: 0.000525187239052; r^2: 0.000494679731086
# Dropping ('req_fields', 'rest_count', 'share_home'):
# 	MSE: 2.58047929901; variance explained: 0.000745705276573; r^2: 0.000728038912943
# Dropping ('fields', 'opt_fields', 'rest_count'):
# 	MSE: 2.4495105538; variance explained: 0.000633842539949; r^2: 0.000619321467827
# Dropping ('fields', 'opt_fields', 'share_home'):
# 	MSE: 2.42169550583; variance explained: 0.000979699759299; r^2: 0.000938866451356
# Dropping ('fields', 'rest_count', 'share_home'):
# 	MSE: 2.41173997782; variance explained: 0.00045161693649; r^2: 0.000446931169716
# Dropping ('opt_fields', 'rest_count', 'share_home'):
# 	MSE: 1.87439768038; variance explained: 0.000609835162816; r^2: 0.000595190863378
# Dropping ('allows_reg_team_create', 'req_fields', 'fields', 'opt_fields'):
# 	MSE: 2.54146014828; variance explained: 0.000954953235797; r^2: 0.00093225232414
# Dropping ('allows_reg_team_create', 'req_fields', 'fields', 'rest_count'):
# 	MSE: 2.48670495366; variance explained: 0.000737096943199; r^2: 0.000709802227624
# Dropping ('allows_reg_team_create', 'req_fields', 'fields', 'share_home'):
# 	MSE: 1.95192094438; variance explained: 0.00103951614192; r^2: 0.00102560922999
# Dropping ('allows_reg_team_create', 'req_fields', 'opt_fields', 'rest_count'):
# 	MSE: 2.0775930366; variance explained: 0.000564859011299; r^2: 0.00054106855523
# Dropping ('allows_reg_team_create', 'req_fields', 'opt_fields', 'share_home'):
# 	MSE: 2.32188432843; variance explained: 0.000901430079028; r^2: 0.00087660621087
# Dropping ('allows_reg_team_create', 'req_fields', 'rest_count', 'share_home'):
# 	MSE: 2.14326933299; variance explained: 0.00068151592307; r^2: 0.000666797935493
# Dropping ('allows_reg_team_create', 'fields', 'opt_fields', 'rest_count'):
# 	MSE: 2.38720708845; variance explained: 0.000838110314995; r^2: 0.000824896966385
# Dropping ('allows_reg_team_create', 'fields', 'opt_fields', 'share_home'):
# 	MSE: 2.68904278082; variance explained: 0.000639190320345; r^2: 0.000603844144798
# Dropping ('allows_reg_team_create', 'fields', 'rest_count', 'share_home'):
# 	MSE: 2.22702977414; variance explained: 0.000832122728387; r^2: 0.000806818795693
# Dropping ('allows_reg_team_create', 'opt_fields', 'rest_count', 'share_home'):
# 	MSE: 1.83233092007; variance explained: 0.000585737042457; r^2: 0.000565062847396
# Dropping ('req_fields', 'fields', 'opt_fields', 'rest_count'):
# 	MSE: 2.52494237356; variance explained: 0.000997539180746; r^2: 0.000977707773603
# Dropping ('req_fields', 'fields', 'opt_fields', 'share_home'):
# 	MSE: 2.10454770461; variance explained: 0.000956566261063; r^2: 0.000931059748608
# Dropping ('req_fields', 'fields', 'rest_count', 'share_home'):
# 	MSE: 2.44650501371; variance explained: 0.000802571810118; r^2: 0.000780477328725
# Dropping ('req_fields', 'opt_fields', 'rest_count', 'share_home'):
# 	MSE: 2.25108469201; variance explained: 0.000570624142229; r^2: 0.000553068080372
# Dropping ('fields', 'opt_fields', 'rest_count', 'share_home'):
# 	MSE: 1.99014506655; variance explained: 0.000672508686427; r^2: 0.000657442445785
# Dropping ('allows_reg_team_create', 'req_fields', 'fields', 'opt_fields', 'rest_count'):
# 	MSE: 2.51645415598; variance explained: 0.000927031472274; r^2: 0.000911296828031
# Dropping ('allows_reg_team_create', 'req_fields', 'fields', 'opt_fields', 'share_home'):
# 	MSE: 2.44627578594; variance explained: 0.000923519488409; r^2: 0.000918694148572
# Dropping ('allows_reg_team_create', 'req_fields', 'fields', 'rest_count', 'share_home'):
# 	MSE: 2.23312248581; variance explained: 0.000663871076802; r^2: 0.000650582944255
# Dropping ('allows_reg_team_create', 'req_fields', 'opt_fields', 'rest_count', 'share_home'):
# 	MSE: 2.36161449232; variance explained: 0.000812218963315; r^2: 0.000788996061762
# Dropping ('allows_reg_team_create', 'fields', 'opt_fields', 'rest_count', 'share_home'):
# 	MSE: 1.83276014577; variance explained: 0.000830088165448; r^2: 0.000819613037993
# Dropping ('req_fields', 'fields', 'opt_fields', 'rest_count', 'share_home'):
# 	MSE: 2.59164198046; variance explained: 0.000916461166643; r^2: 0.000901351462803
# Dropping ('allows_reg_team_create', 'req_fields', 'fields', 'opt_fields', 'rest_count', 'share_home'):
# 	MSE: 2.05738330881; variance explained: 0.000884058242473; r^2: 0.000851335472112
