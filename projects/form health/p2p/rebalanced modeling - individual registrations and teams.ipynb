# %%
import pandas as pd
import numpy as np
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %% [markdown]
# # Data import & prep

# %%
df = pd.read_csv("~/Repositories/datasets/analytics_p2p_registrations.csv")

# %%
drop_cols = ['product', 'sms_trans_vol', 'p2p_trans_vol', 'kiosk_trans_vol', 
             'fb_trans_count', 'sms_trans_count', 'kiosk_trans_count', 'p2p_trans_count', 
             'mobile_visits', 'vt_trans_count', 'vt_trans_vol', 'don_form_trans_count', 
             'don_form_trans_vol', 'form', 'org', 'id', 'fb_trans_vol', 
             'one_time_trans_count', 'one_time_trans_vol', 'rec_trans_count', 
             'rec_trans_vol', 'mobile_trans_count', 'mobile_trans_vol', 
             'mobilevt_trans_count', 'mobilevt_trans_vol']
df = df.drop(drop_cols, axis=1)

# %%
df['reg_conversion'] = df['reg_count'] / df['visits']
df['don_conversion'] = df['don_count'] / df['visits']

# %%
df.columns
# Out:
# Index([u'Unnamed: 0', u'sic', u'ein', u'visits', u'tm_stamp', u'class_count',
#        u'cat_count', u'promo_count', u'rest_count', u'amt_count', u'ded_count',
#        u'fields', u'opt_fields', u'req_fields', u'allows_reg_ind',
#        u'allows_teams', u'allows_reg_team_create', u'allows_reg_team_join',
#        u'allows_opt_reg_donation', u'allows_sub_reg', u'allows_sub_reg_pfp',
#        u'allows_other_don_amt', u'allows_pfp_off_don', u'allows_tfp_off_don',
#        u'allows_soc_post_pfp_tcp', u'share_home', u'share_pfp', u'share_tfp',
#        u'share_therm', u'share_donation', u'allows_social',
#        u'social_templt_count', u'social_auto', u'pcnt_posts', u'mon_posts',
#        u'count_posts', u'date_posts', u'email_templt_count', u'sponsors_count',
#        u'inappr_content', u'reg_count', u'non_fund_reg', u'sub_reg_count',
#        u'teams_count', u'reg_volume', u'don_volume', u'don_count', u'reg_amt',
#        u'reg_conversion', u'don_conversion'],
#       dtype='object')

# %%
ftrs = ['class_count', 'cat_count', 'promo_count', 'rest_count', 'fields', 
        'opt_fields', 'req_fields', 'allows_reg_ind', 'allows_teams', 'allows_reg_team_create',
       'allows_reg_team_join', 'allows_opt_reg_donation', 'allows_sub_reg', 'allows_sub_reg_pfp',
       'share_home', 'share_pfp', 'share_tfp', 'share_therm', 'share_donation', 'allows_social',
       'teams_count', 'reg_count', 'reg_amt', 'reg_conversion', 'don_volume', 'don_count', 'don_conversion']

targets = ['reg_count', 'reg_amt', 'reg_conversion', 'don_volume', 'don_count', 'don_conversion']

# %% [markdown]
# # Individual registration setting

# %% [markdown]
# ## rebalancing & exploration

# %%
df.loc[df.allows_reg_ind==5, 'allows_reg_ind'] = 0
df.allows_reg_ind.value_counts()
# Out:
# 1    202906
# 0     65190
# Name: allows_reg_ind, dtype: int64

# %%
resampled = df[df.allows_reg_ind==0]
resampled = resampled.append(df[df.allows_reg_ind==1].sample(len(resampled)))

# %%
resampled.allows_reg_ind.value_counts()
# Out:
# 1    65190
# 0    65190
# Name: allows_reg_ind, dtype: int64

# %%
cols = ['allows_reg_ind', 'reg_count', 'reg_volume', 'don_volume', 'don_count', 
        'reg_amt', 'reg_conversion', 'don_conversion']
resampled[cols].corr()
# Out:
#                 allows_reg_ind  reg_count  reg_volume  don_volume  don_count  \
# allows_reg_ind        1.000000  -0.005654         NaN   -0.080157  -0.108687
# reg_count            -0.005654   1.000000         NaN   -0.000616  -0.000430
# reg_volume                 NaN        NaN         NaN         NaN        NaN
# don_volume           -0.080157  -0.000616         NaN    1.000000   0.802023
# don_count            -0.108687  -0.000430         NaN    0.802023   1.000000
# reg_amt               0.000260   0.166660         NaN   -0.000932  -0.001364
# reg_conversion        0.000581   0.649562         NaN   -0.019732  -0.023411
# don_conversion       -0.072588  -0.004629         NaN    0.150625   0.173411
#
#                  reg_amt  reg_conversion  don_conversion
# allows_reg_ind  0.000260        0.000581       -0.072588
# reg_count       0.166660        0.649562       -0.004629
# reg_volume           NaN             NaN             NaN
# don_volume     -0.000932       -0.019732        0.150625
# don_count      -0.001364       -0.023411        0.173411
# reg_amt         1.000000        0.132524       -0.000996
# reg_conversion  0.132524        1.000000       -0.018566
# don_conversion -0.000996       -0.018566        1.000000

# %% [markdown]
# ## modeling for feature importance

# %%
for target in targets:
    mse = []
    exv = []
    r2 = []

    df_ftrs = resampled[ftrs].drop(targets, axis=1)
    df_target = resampled[target]

    for i in range(5):
        X_train, X_test, y_train, y_test = train_test_split(df_ftrs, df_target, test_size=0.25)
        rf = RandomForestRegressor(n_estimators=100)
        rf.fit(X_train, y_train)
        y_pred = rf.predict(X_test)
        mse.append(metrics.mean_squared_error(y_test, y_pred))
        exv.append(metrics.explained_variance_score(y_test, y_pred))
        r2.append(metrics.r2_score(y_test, y_pred))

    print("RF for {}:".format(target))
    print("\tMSE: {}".format(np.mean(mse)))
    print("\tExplained variance: {}".format(np.mean(exv)))
    print("\tR^2: {}".format(np.mean(r2)))
    
    for i in range(len(df_ftrs.columns)):
        print("{}: {}".format(df_ftrs.columns[i], rf.feature_importances_[i]))
# Out:
# RF for reg_count:
# 	MSE: 8.85377875868
# 	Explained variance: -0.00884604278655
# 	R^2: -0.00889366666331
# class_count: 0.172760631845
# cat_count: 0.150587421728
# promo_count: 0.168708329615
# rest_count: 0.00121833820406
# fields: 0.123077333703
# opt_fields: 0.0486651563697
# req_fields: 0.0609279667275
# allows_reg_ind: 0.0340915685348
# allows_teams: 0.0224022728343
# allows_reg_team_create: 0.00730796354411
# allows_reg_team_join: 0.00855843880182
# allows_opt_reg_donation: 0.0461368838235
# allows_sub_reg: 0.0
# allows_sub_reg_pfp: 0.00116029335043
# share_home: 0.0
# share_pfp: 0.0
# share_tfp: 0.0
# share_therm: 0.0
# share_donation: 0.0
# allows_social: 3.1499313129e-05
# teams_count: 0.154365901604
# RF for reg_amt:
# 	MSE: 2679.60410356
# 	Explained variance: -0.0229903328509
# 	R^2: -0.0230201115001
# class_count: 0.116811379903
# cat_count: 0.141328255679
# promo_count: 0.210782985784
# rest_count: 0.0159182728579
# fields: 0.107633326583
# opt_fields: 0.0907029959821
# req_fields: 0.0633237318789
# allows_reg_ind: 0.0422447466773
# allows_teams: 0.0190501320999
# allows_reg_team_create: 0.0134989102533
# allows_reg_team_join: 0.00918692374562
# allows_opt_reg_donation: 0.00739383819558
# allows_sub_reg: 1.49757334573e-06
# allows_sub_reg_pfp: 0.00741212611058
# share_home: 0.0
# share_pfp: 0.0
# share_tfp: 0.0
# share_therm: 0.0
# share_donation: 0.0
# allows_social: 1.00987334824e-06
# teams_count: 0.154709866803
# RF for reg_conversion:
# 	MSE: 2.48442145608
# 	Explained variance: -0.00415526704345
# 	R^2: -0.00419272012278
# class_count: 0.137263383416
# cat_count: 0.213016704451
# promo_count: 0.159428005927
# rest_count: 0.00773863404905
# fields: 0.105484417493
# opt_fields: 0.0472957657086
# req_fields: 0.0890585008711
# allows_reg_ind: 0.0424387515128
# allows_teams: 0.0263686119135
# allows_reg_team_create: 0.0239241002085
# allows_reg_team_join: 0.0165484819875
# allows_opt_reg_donation: 0.051998957129
# allows_sub_reg: 1.60268498234e-05
# allows_sub_reg_pfp: 0.0111802426498
# share_home: 0.0
# share_pfp: 0.0
# share_tfp: 0.0
# share_therm: 0.0
# share_donation: 0.0
# allows_social: 3.62734017426e-05
# teams_count: 0.0682031424316
# RF for don_volume:
# 	MSE: 65453.8973724
# 	Explained variance: 0.418863622468
# 	R^2: 0.418842655144
# class_count: 0.437685261311
# cat_count: 0.0565293582514
# promo_count: 0.0250770776934
# rest_count: 3.99682106631e-05
# fields: 0.0143554539659
# opt_fields: 0.00815552460142
# req_fields: 0.0158913029642
# allows_reg_ind: 0.0151237853575
# allows_teams: 0.00550332236269
# allows_reg_team_create: 0.023882028107
# allows_reg_team_join: 0.00112635573272
# allows_opt_reg_donation: 0.00523036933064
# allows_sub_reg: 1.81848638284e-07
# allows_sub_reg_pfp: 3.19536171052e-06
# share_home: 0.0
# share_pfp: 0.0
# share_tfp: 0.0
# share_therm: 0.0
# share_donation: 0.0
# allows_social: 0.0
# teams_count: 0.391396814901
# RF for don_count:
# 	MSE: 7.42340720782
# 	Explained variance: 0.529213956453
# 	R^2: 0.52918630222
# class_count: 0.327011235207
# cat_count: 0.0567660626121
# promo_count: 0.0175501971863
# rest_count: 7.42827319787e-05
# fields: 0.0168344405033
# opt_fields: 0.00680604815949
# req_fields: 0.0185059100714
# allows_reg_ind: 0.0471726018863
# allows_teams: 0.00734587954588
# allows_reg_team_create: 0.0376838717796
# allows_reg_team_join: 0.000715104382433
# allows_opt_reg_donation: 0.0257747302802
# allows_sub_reg: 0.0
# allows_sub_reg_pfp: 1.83688434995e-06
# share_home: 0.0
# share_pfp: 0.0
# share_tfp: 0.0
# share_therm: 0.0
# share_donation: 0.0
# allows_social: 0.0
# teams_count: 0.43775779877
# RF for don_conversion:
# 	MSE: 0.00379103650464
# 	Explained variance: 0.0553254629112
# 	R^2: 0.0552553288825
# class_count: 0.185221340565
# cat_count: 0.165066789547
# promo_count: 0.134881077813
# rest_count: 0.0172759920046
# fields: 0.104609208259
# opt_fields: 0.05358673656
# req_fields: 0.0545661794283
# allows_reg_ind: 0.0739054061616
# allows_teams: 0.0317143696389
# allows_reg_team_create: 0.079573252465
# allows_reg_team_join: 0.0254483912043
# allows_opt_reg_donation: 0.027893754408
# allows_sub_reg: 1.95449733532e-05
# allows_sub_reg_pfp: 0.00106547675902
# share_home: 0.0
# share_pfp: 0.0
# share_tfp: 0.0
# share_therm: 0.0
# share_donation: 0.0
# allows_social: 0.0
# teams_count: 0.0451724802122

# %% [markdown]
# # Allows teams setting

# %% [markdown]
# ## rebalancing and exploration

# %%
df.loc[df.allows_teams==5, 'allows_teams'] = 0
df.allows_teams.value_counts()
# Out:
# 1    227966
# 0     40130
# Name: allows_teams, dtype: int64

# %%
resampled = df[df.allows_teams==0]
resampled = resampled.append(df[df.allows_teams==1].sample(len(resampled)))
resampled.allows_teams.value_counts()
# Out:
# 1    40130
# 0    40130
# Name: allows_teams, dtype: int64

# %%
cols = ['allows_teams', 'reg_count', 'reg_volume', 'don_volume', 'don_count', 
        'reg_amt', 'reg_conversion', 'don_conversion']
resampled[cols].corr()
# Out:
#                 allows_teams  reg_count  reg_volume  don_volume  don_count  \
# allows_teams        1.000000  -0.004526         NaN    0.046075   0.096507
# reg_count          -0.004526   1.000000         NaN   -0.000031  -0.003862
# reg_volume               NaN        NaN         NaN         NaN        NaN
# don_volume          0.046075  -0.000031         NaN    1.000000   0.730526
# don_count           0.096507  -0.003862         NaN    0.730526   1.000000
# reg_amt            -0.003325   0.267521         NaN   -0.001755   0.000837
# reg_conversion     -0.011977   0.756511         NaN   -0.024516  -0.027677
# don_conversion     -0.017141  -0.006616         NaN    0.210053   0.218075
#
#                  reg_amt  reg_conversion  don_conversion
# allows_teams   -0.003325       -0.011977       -0.017141
# reg_count       0.267521        0.756511       -0.006616
# reg_volume           NaN             NaN             NaN
# don_volume     -0.001755       -0.024516        0.210053
# don_count       0.000837       -0.027677        0.218075
# reg_amt         1.000000        0.206503       -0.000513
# reg_conversion  0.206503        1.000000       -0.025962
# don_conversion -0.000513       -0.025962        1.000000

# %%
for target in targets:
    mse = []
    exv = []
    r2 = []

    df_ftrs = resampled[ftrs].drop(targets, axis=1)
    df_target = resampled[target]

    for i in range(5):
        X_train, X_test, y_train, y_test = train_test_split(df_ftrs, df_target, test_size=0.25)
        rf = RandomForestRegressor(n_estimators=100)
        rf.fit(X_train, y_train)
        y_pred = rf.predict(X_test)
        mse.append(metrics.mean_squared_error(y_test, y_pred))
        exv.append(metrics.explained_variance_score(y_test, y_pred))
        r2.append(metrics.r2_score(y_test, y_pred))

    print("RF for {}:".format(target))
    print("\tMSE: {}".format(np.mean(mse)))
    print("\tExplained variance: {}".format(np.mean(exv)))
    print("\tR^2: {}".format(np.mean(r2)))
    
    for i in range(len(df_ftrs.columns)):
        print("{}: {}".format(df_ftrs.columns[i], rf.feature_importances_[i]))
# Out:
# RF for reg_count:
# 	MSE: 5.14983248856
# 	Explained variance: -0.0132367120577
# 	R^2: -0.0133302365971
# class_count: 0.167001143094
# cat_count: 0.180790024998
# promo_count: 0.175152380422
# rest_count: 0.00307167727992
# fields: 0.0910506937304
# opt_fields: 0.0531629340302
# req_fields: 0.067088211083
# allows_reg_ind: 0.031862809494
# allows_teams: 0.0141326948815
# allows_reg_team_create: 0.0174222300098
# allows_reg_team_join: 0.0141484079552
# allows_opt_reg_donation: 0.0572930004653
# allows_sub_reg: 9.73955723664e-06
# allows_sub_reg_pfp: 0.000472257401993
# share_home: 0.0
# share_pfp: 0.0
# share_tfp: 0.0
# share_therm: 0.0
# share_donation: 0.0
# allows_social: 0.00203793639185
# teams_count: 0.125303859205
# RF for reg_amt:
# 	MSE: 1760.2470753
# 	Explained variance: -0.0124806995644
# 	R^2: -0.0125634735732
# class_count: 0.384766277688
# cat_count: 0.0679616174405
# promo_count: 0.134175577674
# rest_count: 0.00618372514252
# fields: 0.039659849728
# opt_fields: 0.0257268311925
# req_fields: 0.0176056696685
# allows_reg_ind: 0.0336931509763
# allows_teams: 0.0438846357164
# allows_reg_team_create: 0.144465719059
# allows_reg_team_join: 0.0188933237963
# allows_opt_reg_donation: 0.0243255617368
# allows_sub_reg: 3.22048333867e-06
# allows_sub_reg_pfp: 0.0152578192222
# share_home: 0.0
# share_pfp: 0.0
# share_tfp: 0.0
# share_therm: 0.0
# share_donation: 0.0
# allows_social: 5.32465788011e-07
# teams_count: 0.0433964880093
# RF for reg_conversion:
# 	MSE: 1.728230922
# 	Explained variance: -0.00512916150678
# 	R^2: -0.00520344772212
# class_count: 0.126841677243
# cat_count: 0.17513020174
# promo_count: 0.216982331173
# rest_count: 0.00842419772313
# fields: 0.127315934245
# opt_fields: 0.0884137048415
# req_fields: 0.0951412699259
# allows_reg_ind: 0.0390384361753
# allows_teams: 0.028603790808
# allows_reg_team_create: 0.0185368066033
# allows_reg_team_join: 0.0208146105975
# allows_opt_reg_donation: 0.0208605937815
# allows_sub_reg: 2.99114967814e-05
# allows_sub_reg_pfp: 0.00780557187396
# share_home: 0.0
# share_pfp: 0.0
# share_tfp: 0.0
# share_therm: 0.0
# share_donation: 0.0
# allows_social: 8.7407876046e-05
# teams_count: 0.0259735538964
# RF for don_volume:
# 	MSE: 50719.7585514
# 	Explained variance: 0.289445313636
# 	R^2: 0.289396918249
# class_count: 0.32838689424
# cat_count: 0.0844281404436
# promo_count: 0.0589470830312
# rest_count: 0.000293922879004
# fields: 0.0332284993038
# opt_fields: 0.0268988766751
# req_fields: 0.0495417146031
# allows_reg_ind: 0.0389279761069
# allows_teams: 0.00954260601017
# allows_reg_team_create: 0.0374982684137
# allows_reg_team_join: 0.00425260738672
# allows_opt_reg_donation: 0.0254461962303
# allows_sub_reg: 1.89080503628e-06
# allows_sub_reg_pfp: 7.89684079754e-06
# share_home: 0.0
# share_pfp: 0.0
# share_tfp: 0.0
# share_therm: 0.0
# share_donation: 0.0
# allows_social: 0.0
# teams_count: 0.302597427031
# RF for don_count:
# 	MSE: 4.28395455013
# 	Explained variance: 0.431141125668
# 	R^2: 0.431105482372
# class_count: 0.29582934984
# cat_count: 0.0568303380356
# promo_count: 0.0425588710791
# rest_count: 0.000250321089307
# fields: 0.0287476613362
# opt_fields: 0.0238245713404
# req_fields: 0.0627181758949
# allows_reg_ind: 0.07886993352
# allows_teams: 0.00764364463566
# allows_reg_team_create: 0.0659996719369
# allows_reg_team_join: 0.00248830353085
# allows_opt_reg_donation: 0.0356228892955
# allows_sub_reg: 0.0
# allows_sub_reg_pfp: 5.56719755745e-06
# share_home: 0.0
# share_pfp: 0.0
# share_tfp: 0.0
# share_therm: 0.0
# share_donation: 0.0
# allows_social: 0.0
# teams_count: 0.298610701268
# RF for don_conversion:
# 	MSE: 0.00193309158161
# 	Explained variance: 0.112840712673
# 	R^2: 0.112769766442
# class_count: 0.148566021457
# cat_count: 0.189170126594
# promo_count: 0.144690134811
# rest_count: 0.00660239178561
# fields: 0.125835199551
# opt_fields: 0.0817123890752
# req_fields: 0.0461881282783
# allows_reg_ind: 0.101339460868
# allows_teams: 0.0651682908479
# allows_reg_team_create: 0.022531244077
# allows_reg_team_join: 0.0138110623868
# allows_opt_reg_donation: 0.0320689557983
# allows_sub_reg: 2.91938256626e-05
# allows_sub_reg_pfp: 0.00115338424825
# share_home: 0.0
# share_pfp: 0.0
# share_tfp: 0.0
# share_therm: 0.0
# share_donation: 0.0
# allows_social: 0.0
# teams_count: 0.0211340163967
