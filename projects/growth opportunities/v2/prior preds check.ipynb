# %%
import sys
sys.path.append("../../../scripts/")
from s3_support import *

import pandas as pd
import datetime

# %%
preds = get_dataframe_from_file("qgiv-stats-data", 'preds.growth.csv')

# %%
preds.tail(3)
# Out:
#        org  low_recurring  high_events  high_sms  only_p2p  low_dl  total  \
# 17   76803           True         True     False     False   False      2
# 18  444526           True        False     False      True   False      2
# 19   44022           True        False      True     False   False      2
#
#     not_cms_active  not_using_widgets  no_recent_logins  \
# 17            True              False              True
# 18            True               True              True
# 19            True               True              True
#
#                           date
# 17  2021-04-12 08:23:39.342737
# 18  2021-04-12 08:23:39.342737
# 19  2021-04-12 08:23:39.342737

# %%
preds['org'] = preds['org'].astype(int)
preds['date'] = pd.to_datetime(preds['date'])
six_months_ago = datetime.datetime.today() - datetime.timedelta(6*365/12)
prior_preds = preds[preds['date']>=six_months_ago]
len(prior_preds)
# Out:
# 20

# %%
six_months_ago
# Out:
# datetime.datetime(2020, 10, 11, 20, 39, 20, 264391)
