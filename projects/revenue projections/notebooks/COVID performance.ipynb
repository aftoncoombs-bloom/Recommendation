# %%
import pandas as pd
import numpy as np

import sys
sys.path.insert(1, '../../../scripts/')
from s3_support import *

# %% [markdown]
# # Load data

# %%
q = '''select 
        org, 
        date_trunc('month', date) as month, 
        count(id) as count, 
        sum(amount) as volume
    from transactions
        where status='A'
        group by org, date_trunc('month', date)
        order by date_trunc('month', date) desc'''
df = redshift_query_read(q)
df['month'] = pd.to_datetime(df['month'])
df['month_cat'] = df['month'].dt.month

# %%
orgs = get_dataframe_from_file("qgiv-stats-data", "organizations.names.csv")

# %%
def get_segment_for_org(org):
    if len(orgs[orgs['id']==org]['segment']) > 0:
        return orgs[orgs['id']==org]['segment'].iloc[0]
    else:
        return None
    
df['segment'] = df['org'].apply(get_segment_for_org)

# %%
len(df)
# Out:
# 138311

# %%
orgs['segment'].value_counts().reset_index()
# Out:
#                                                 index  segment
# 0                                 P - Human Services       703
# 1                X - Religion, Spiritual Development       647
# 2                       B - Educational Institutions       571
# 3                                        Z - Unknown       460
# 4                              O - Youth Development       342
# 5                  A - Arts, Culture, and Humanities       321
# 6             E - Health, General and Rehabilitative       211
# 7     T - Philanthropy, Voluntarism, and Grantmaking       194
# 8       S - Community Improvement, Capacity Building       164
# 9        G - Disease, Disorders, Medical Disciplines       163
# 10                              L - Housing, Shelter       141
# 11                                        D - Animal       128
# 12         F - Mental Health and Crisis Intervention       125
# 13          C - Environmental Advocacy and Protection      125
# 14  Q - International, Foreign Affairs, and Nation...      119
# 15        N - Recreation, Sports, Leisure, Athletics       109
# 16                   K - Agriculture, Food, Nutrition       83
# 17                       W - Public, Society Benefit        72
# 18         R - Civil Rights, Social Action, Advocacy        67
# 19                          I - Crime, Legal Related        67
# 20                       J - Employment, Job Related        38
# 21                M - Public Safety, Disaster Relief        34
# 22                              H - Medical Research        31
# 23        Y - Mutual/Membership Benefit Organizations       13
# 24            V - Social Science Research Institutes        12
# 25     U - Science and Technology Research Institutes        9
# 26  B - Educational Institutions , O - Youth Devel...        1
# 27  T - Philanthropy, Voluntarism, and Grantmaking...        1
# 28               O - Youth Development , Z - Unknown         1
# 29                         Z - Unknown , Z - Unknown         1
# 30  Z - Unknown , R - Civil Rights, Social Action,...        1
# 31                           D - Animal , D - Animal         1
# 32  S - Community Improvement, Capacity Building ,...        1
# 33  T - Philanthropy, Voluntarism, and Grantmaking...        1
# 34      L - Housing, Shelter , O - Youth Development         1

# %% [markdown]
# # Looking at segment wide performance monthly YoY

# %%
segment_grpd = df.groupby(['segment', 'month'])[['volume', 'count']].sum().reset_index()

# %%
segment_grpd['month_cat'] = segment_grpd['month'].dt.month
segment_grpd = segment_grpd[segment_grpd['volume']>0]

# %%
segment_grpd.head(3)
# Out:
#                                segment      month   volume  count  month_cat
# 9   A - Arts, Culture, and Humanities  2008-09-01  9986.00    193          9
# 10  A - Arts, Culture, and Humanities  2008-10-01  8189.42    118         10
# 11  A - Arts, Culture, and Humanities  2008-11-01  8431.42    138         11

# %% [markdown]
# ## Volume

# %%
segmented_data = None
for segment in segment_grpd['segment'].unique():
    # slice non-zero segment observations
    this_segment = segment_grpd[(segment_grpd['segment']==segment)&(segment_grpd['volume']>0)].copy()
    
    # calculate volume and count growth
    this_segment['month_pct_change'] = this_segment.groupby('month_cat')['volume'].apply(pd.Series.pct_change)
    this_segment.dropna(inplace=True)
    
    # isolate January - April
    this_segment = this_segment[this_segment['month_cat'].isin([1, 2, 3, 4])]
    
    # get mean history and latest values
    segment_an = this_segment[(this_segment['month'].dt.year>2014)&(this_segment['month'].dt.year!=2020)].groupby('month_cat')['month_pct_change'].mean().reset_index()
    
    segment_an = segment_an.merge(this_segment[this_segment['month'].dt.year==2020][['month_cat', 'month_pct_change']], on="month_cat")
    segment_an.columns = ['month_cat', 'historical_mean_growth', '2020_growth']
    segment_an['segment'] = segment
    
    if segmented_data is None:
        segmented_data = segment_an
    else:
        segmented_data = segmented_data.append(segment_an)

# %%
segmented_data.tail()
# Out:
#    month_cat  historical_mean_growth  2020_growth  \
# 3        4.0                0.140134     0.092246
# 0        1.0               -0.161501    -0.213468
# 1        2.0               -0.148962    -0.195902
# 2        3.0               -0.097561    -0.221070
# 3        4.0               -0.140008     1.351812
#
#                                        segment
# 3  Y - Mutual/Membership Benefit Organizations
# 0                                 Z - Unknown
# 1                                 Z - Unknown
# 2                                 Z - Unknown
# 3                                 Z - Unknown

# %%
segmented_monthly = segmented_data.copy()

# %%
segmented_data['2020_growth_diff'] = (segmented_data['2020_growth'] - segmented_data['historical_mean_growth']) * 100

# %%
pvt = segmented_data[['segment', 'month_cat', '2020_growth_diff']].pivot(index='segment', columns='month_cat', values="2020_growth_diff").reset_index()

# %%
pvt.columns = ['segment', 'jan', 'feb', 'mar', 'apr']

# %%
wcounts = pvt.merge(orgs['segment'].value_counts().reset_index(), left_on="segment", right_on="index")
wcounts.drop("index", axis=1, inplace=True)
wcounts.columns = ['segment', 'jan', 'feb', 'mar', 'apr', 'count']
wcounts
# Out:
#                                               segment         jan         feb  \
# 0                  A - Arts, Culture, and Humanities    28.646150   74.780825
# 1                       B - Educational Institutions   -21.232749    4.938779
# 2           C - Environmental Advocacy and Protection  -45.623082   27.301017
# 3                                         D - Animal   243.933325    2.807322
# 4             E - Health, General and Rehabilitative   -24.463958  -46.689132
# 5          F - Mental Health and Crisis Intervention     2.364785    6.510750
# 6        G - Disease, Disorders, Medical Disciplines   -33.112721  -22.190752
# 7                               H - Medical Research     1.592758  -29.792980
# 8                           I - Crime, Legal Related    19.912921   17.059952
# 9                        J - Employment, Job Related    65.403423   82.947975
# 10                   K - Agriculture, Food, Nutrition  -20.466852   41.384104
# 11                              L - Housing, Shelter   -39.763361  -58.307554
# 12                M - Public Safety, Disaster Relief    35.101390  -65.534107
# 13        N - Recreation, Sports, Leisure, Athletics   -58.064845  -30.128278
# 14                             O - Youth Development   -32.969527  -29.174941
# 15                                P - Human Services     7.998860   50.265910
# 16  Q - International, Foreign Affairs, and Nation...  -89.913796  -80.624914
# 17         R - Civil Rights, Social Action, Advocacy   -39.307073  111.485629
# 18      S - Community Improvement, Capacity Building   -30.957160  -21.562010
# 19    T - Philanthropy, Voluntarism, and Grantmaking     7.832870    1.487105
# 20  T - Philanthropy, Voluntarism, and Grantmaking...         NaN         NaN
# 21     U - Science and Technology Research Institutes  269.363458   74.637043
# 22            V - Social Science Research Institutes     0.401998  -87.595143
# 23                       W - Public, Society Benefit    86.906811  246.015610
# 24               X - Religion, Spiritual Development   -29.859166  -28.839721
# 25        Y - Mutual/Membership Benefit Organizations   55.229400 -317.163778
# 26                                       Z - Unknown    -5.196684   -4.694057
#
#               mar          apr  count
# 0       -2.860670   -31.005603    321
# 1      -27.510901   -47.805313    571
# 2      -49.006677   -43.679515    125
# 3      -42.246739   -23.369846    128
# 4      -67.323373   -81.913409    211
# 5      -13.296864   -44.624931    125
# 6     -140.598629  -103.643103    163
# 7      -77.889869   -66.822585     31
# 8      -74.994062    38.207685     67
# 9     -130.603875   -97.669287     38
# 10     575.771295  1537.372241     83
# 11      23.506613    75.420136    141
# 12     -31.895127   263.729345     34
# 13     -70.860310   -36.092675    109
# 14     -60.941887  -127.837945    342
# 15      62.331027   156.282189    703
# 16     -92.271542   -62.251410    119
# 17     -40.268300    36.548398     67
# 18      90.718380    95.705112    164
# 19      -3.901202   -36.251226    194
# 20 -144485.467128  -377.115385      1
# 21     -46.389704  -159.691308      9
# 22     -69.576172   148.398948     12
# 23     -24.283797     3.628858     72
# 24     -20.947915     0.165907    647
# 25     -58.120786    -4.788733     13
# 26     -12.350853   149.182040    460

# %% [markdown]
# ## Count

# %%
segmented_data = None
for segment in segment_grpd['segment'].unique():
    # slice non-zero segment observations
    this_segment = segment_grpd[(segment_grpd['segment']==segment)&(segment_grpd['count']>0)].copy()
    
    # calculate volume and count growth
    this_segment['month_pct_change'] = this_segment.groupby('month_cat')['count'].apply(pd.Series.pct_change)
    this_segment.dropna(inplace=True)
    
    # isolate January - April
    this_segment = this_segment[this_segment['month_cat'].isin([1, 2, 3, 4])]
    
    # get mean history and latest values
    segment_an = this_segment[(this_segment['month'].dt.year>2012)&(this_segment['month'].dt.year!=2020)].groupby('month_cat')['month_pct_change'].mean().reset_index()
    
    segment_an = segment_an.merge(this_segment[this_segment['month'].dt.year==2020][['month_cat', 'month_pct_change']], on="month_cat")
    segment_an.columns = ['month_cat', 'historical_mean_growth', '2020_growth']
    segment_an['segment'] = segment
    
    if segmented_data is None:
        segmented_data = segment_an
    else:
        segmented_data = segmented_data.append(segment_an)

# %%
segmented_data.tail()
# Out:
#    month_cat  historical_mean_growth  2020_growth  \
# 3        4.0                1.153361     0.762791
# 0        1.0                0.493192    -0.143825
# 1        2.0                0.336130     0.228705
# 2        3.0                0.535859    -0.514674
# 3        4.0                0.496664    -0.320887
#
#                                        segment
# 3  Y - Mutual/Membership Benefit Organizations
# 0                                 Z - Unknown
# 1                                 Z - Unknown
# 2                                 Z - Unknown
# 3                                 Z - Unknown

# %%
segmented_monthly.columns = ['month_cat', 'mean_volume_growth', '2020_volume_growth', 'segment']
segmented_monthly = segmented_monthly.merge(segmented_data, on=['month_cat', 'segment'])
segmented_monthly = segmented_monthly[['segment', 'month_cat', 'mean_volume_growth', '2020_volume_growth', 'historical_mean_growth', '2020_growth']]
segmented_monthly.columns = ['segment', 'month', 'mean_volume_growth', '2020_volume_growth', 'mean_count_growth', '2020_count_growth']
segmented_monthly.head()
# Out:
#                               segment  month  mean_volume_growth  \
# 0  A - Arts, Culture, and Humanities     1.0            0.148668
# 1  A - Arts, Culture, and Humanities     2.0            0.185996
# 2  A - Arts, Culture, and Humanities     3.0            0.232048
# 3  A - Arts, Culture, and Humanities     4.0            0.177452
# 4       B - Educational Institutions     1.0            0.429313
#
#    2020_volume_growth  mean_count_growth  2020_count_growth
# 0            0.435129           0.403940          -0.344016
# 1            0.933805           0.346160           0.261810
# 2            0.203441           0.387324          -0.058195
# 3           -0.132604           0.315170           0.045358
# 4            0.216986           0.323325           0.409008

# %%
segmented_monthly.to_csv("q1_2020.csv", index=False)

# %%
segmented_data['2020_growth_diff'] = (segmented_data['2020_growth'] - segmented_data['historical_mean_growth']) * 100

pvt = segmented_data[['segment', 'month_cat', '2020_growth_diff']].pivot(index='segment', columns='month_cat', values="2020_growth_diff").reset_index()
pvt.columns = ['segment', 'jan', 'feb', 'mar', 'apr']

wcounts = pvt.merge(orgs['segment'].value_counts().reset_index(), left_on="segment", right_on="index")
wcounts.drop("index", axis=1, inplace=True)
wcounts.columns = ['segment', 'jan', 'feb', 'mar', 'apr', 'count']
wcounts
# Out:
#                                               segment         jan         feb  \
# 0                  A - Arts, Culture, and Humanities   -74.795688   -8.434993
# 1                       B - Educational Institutions     8.568291    3.024386
# 2           C - Environmental Advocacy and Protection  -77.175644  -24.685980
# 3                                         D - Animal   216.243954  -24.309848
# 4             E - Health, General and Rehabilitative    -0.450100  -13.831070
# 5          F - Mental Health and Crisis Intervention   -17.646042  -23.264634
# 6        G - Disease, Disorders, Medical Disciplines   -31.138466  -72.608199
# 7                               H - Medical Research   -82.511532  -28.965118
# 8                           I - Crime, Legal Related    -7.849189  -90.426402
# 9                        J - Employment, Job Related   360.889604  113.627915
# 10                   K - Agriculture, Food, Nutrition  -66.607575  -40.970604
# 11                              L - Housing, Shelter   -42.189844  -42.859800
# 12                M - Public Safety, Disaster Relief  -103.711400  -25.735215
# 13        N - Recreation, Sports, Leisure, Athletics   -51.357130  -26.842885
# 14                             O - Youth Development   -50.644987  -51.026479
# 15                                P - Human Services     0.953596  161.555083
# 16  Q - International, Foreign Affairs, and Nation... -123.282313 -124.620599
# 17         R - Civil Rights, Social Action, Advocacy    50.657623   90.775051
# 18      S - Community Improvement, Capacity Building   -12.231798  -20.206375
# 19    T - Philanthropy, Voluntarism, and Grantmaking   -35.243116  -35.150110
# 20  T - Philanthropy, Voluntarism, and Grantmaking...         NaN         NaN
# 21     U - Science and Technology Research Institutes   53.870991   82.417038
# 22            V - Social Science Research Institutes   -34.412741 -108.805228
# 23                       W - Public, Society Benefit     4.814342  140.453625
# 24               X - Religion, Spiritual Development   -48.164124  -41.346575
# 25        Y - Mutual/Membership Benefit Organizations -347.901549  -80.699228
# 26                                       Z - Unknown   -63.701737  -10.742520
#
#             mar         apr  count
# 0    -44.551879  -26.981239    321
# 1    -61.420011  -85.301326    571
# 2   -127.453685 -150.066172    125
# 3    -50.692024   -6.161769    128
# 4    -73.390825 -112.649574    211
# 5    -36.339458  -47.035618    125
# 6   -154.164565 -123.449217    163
# 7   -138.768528 -105.939432     31
# 8   -129.759771  -81.075039     67
# 9   -199.428068 -104.183113     38
# 10   267.822353  475.104499     83
# 11    12.607055   28.183763    141
# 12  -391.162787  656.908992     34
# 13    -6.271033   55.202536    109
# 14  -128.033388 -191.516534    342
# 15     4.513904   46.126462    703
# 16   -93.211905  -81.657683    119
# 17    -3.211901   12.241571     67
# 18    43.289662  -41.236867    164
# 19   -47.778859  -50.821332    194
# 20 -1276.923077 -133.333333      1
# 21  -724.059194 -354.519733      9
# 22   -79.612507  129.116380     12
# 23    67.553369   60.897888     72
# 24   -48.536974  -38.059923    647
# 25   -80.714021  -39.057065     13
# 26  -105.053307  -81.755143    460
