# %%
import pandas as pd
import sys, datetime
sys.path.insert(1, '../../../scripts/')
from s3_support import *

# %% [markdown]
# # SQL output

# %%
sql_output = '''mysql> SELECT LYR.*, O.csm, A.username FROM LowYearRoundOrgs as LYR left join Organization as O on LYR.org=O.id left join GlobalAccounts as A on O.csm=A.id;
+--------+---------------------+---------+---------------------------+
| org    | dateCreated         | csm     | username                  |
+--------+---------------------+---------+---------------------------+
|     97 | 2021-07-26 00:00:00 |       0 | NULL                      |
|    140 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
|    144 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|    153 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
|    177 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|    208 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|    223 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|    247 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|    262 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|    341 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|    429 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
|    442 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|    612 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|    683 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
|    729 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|    740 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
|    786 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|    810 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|    862 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|    946 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|    974 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|   1002 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
|   1019 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|   1074 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|   1207 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|   1283 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
|   1285 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
|   1310 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|   1361 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|   1370 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
|   1463 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|   1575 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
|   1604 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|   1637 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|   1790 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|   1807 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
|   4021 | 2021-07-26 00:00:00 |       0 | NULL                      |
|   8115 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|   9139 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
|  10173 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
|  16333 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|  18383 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|  19417 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|  19421 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|  19448 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|  19450 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|  19457 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
|  20436 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
|  20443 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|  20450 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
|  20461 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
|  21468 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|  22499 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|  23523 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
|  27621 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
|  27623 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
|  27627 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|  27647 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|  27651 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|  29674 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|  29683 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
|  29695 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|  29715 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|  29720 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|  29724 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
|  29727 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
|  29728 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
|  29734 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
|  29735 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
|  29737 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
|  29747 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
|  29756 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
|  29757 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|  29768 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|  31741 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|  31746 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|  31747 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|  31762 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|  31768 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|  31769 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
|  31771 | 2021-07-26 00:00:00 |       0 | NULL                      |
|  31772 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
|  31773 | 2021-07-26 00:00:00 |       0 | NULL                      |
|  31795 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
|  31796 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|  31803 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
|  31821 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|  31822 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
|  31831 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|  31833 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|  33767 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
|  33779 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|  33785 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|  34788 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
|  34803 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
|  35816 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
|  36839 | 2021-07-26 00:00:00 |       0 | NULL                      |
|  36840 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|  37865 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
|  37877 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|  38888 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
|  38890 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|  38891 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
|  38896 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|  38900 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
|  38908 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|  38922 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|  38927 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
|  39911 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
|  39932 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
|  39944 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|  39949 | 2021-07-26 00:00:00 |       0 | NULL                      |
|  40937 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
|  40939 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|  40943 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|  40944 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|  40950 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
|  40960 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|  40963 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
|  40973 | 2021-07-26 00:00:00 |       0 | NULL                      |
|  41962 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|  41968 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
|  41971 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|  41973 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
|  41977 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|  41992 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
|  42984 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|  42993 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
|  42996 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|  44013 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|  44019 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
|  44020 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|  44022 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|  44026 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
|  44027 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
|  44037 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
|  44038 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
|  47108 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
|  47109 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|  48135 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|  50179 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|  52231 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
|  52232 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|  56323 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|  56324 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
|  60419 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
|  71684 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
|  83971 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
|  84995 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
|  89091 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|  94211 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
| 100355 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
| 108547 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
| 109571 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
| 110596 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
| 111620 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
| 118787 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
| 126979 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
| 129027 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
| 135174 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
| 138243 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
| 149507 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
| 152579 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
| 166916 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
| 174083 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
| 178180 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
| 179204 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
| 199683 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
| 205827 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
| 206851 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
| 207876 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
| 211971 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
| 212995 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
| 214020 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
| 227331 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
| 231427 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
| 236547 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
| 239620 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
| 240644 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
| 245763 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
| 246787 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
| 250883 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
| 251907 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
| 259076 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
| 261124 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
| 263171 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
| 265220 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
| 269315 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
| 274436 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
| 287747 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
| 293891 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
| 301060 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
| 302083 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
| 319491 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
| 320517 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
| 322563 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
| 327683 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
| 332804 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
| 342019 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
| 343043 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
| 344067 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
| 345091 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
| 351237 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
| 352259 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
| 356355 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
| 358403 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
| 367619 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
| 376835 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
| 377860 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
| 379907 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
| 382979 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
| 387076 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
| 391171 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
|
| 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
| 446500 | 2021-07-26 00:00:00 |   14045 | brittany.bedford@qgiv.com |
| 446502 | 2021-07-26 00:00:00 | 1220603 | windy.keene@qgiv.com      |
| 446503 | 2021-07-26 00:00:00 | 1129028 | ammon.lowman@qgiv.com     |
| 446514 | 2021-07-26 00:00:00 | 1220601 | heidi.morris@qgiv.com     |
+--------+---------------------+---------+---------------------------+
1603 rows in set (0.02 sec)
'''

# %% [markdown]
# # extracting org ID's

# %%
sql_output[:200]
# Out:
# 'mysql> SELECT LYR.*, O.csm, A.username FROM LowYearRoundOrgs as LYR left join Organization as O on LYR.org=O.id left join GlobalAccounts as A on O.csm=A.id;\n+--------+---------------------+---------+-'

# %%
sql_output_lines = sql_output.split('\n')
sql_output_lines[:5]
# Out:
# ['mysql> SELECT LYR.*, O.csm, A.username FROM LowYearRoundOrgs as LYR left join Organization as O on LYR.org=O.id left join GlobalAccounts as A on O.csm=A.id;',
#  '+--------+---------------------+---------+---------------------------+',
#  '| org    | dateCreated         | csm     | username                  |',
#  '+--------+---------------------+---------+---------------------------+',
#  '|     97 | 2021-07-26 00:00:00 |       0 | NULL                      |']

# %%
[l.split('|') for l in sql_output_lines[:5]]
# Out:
# [['mysql> SELECT LYR.*, O.csm, A.username FROM LowYearRoundOrgs as LYR left join Organization as O on LYR.org=O.id left join GlobalAccounts as A on O.csm=A.id;'],
#  ['+--------+---------------------+---------+---------------------------+'],
#  ['',
#   ' org    ',
#   ' dateCreated         ',
#   ' csm     ',
#   ' username                  ',
#   ''],
#  ['+--------+---------------------+---------+---------------------------+'],
#  ['',
#   '     97 ',
#   ' 2021-07-26 00:00:00 ',
#   '       0 ',
#   ' NULL                      ',
#   '']]

# %%
d = []
errors = []
for l in sql_output_lines:
    parts = l.split('|')
    
    try:
        d.append({
            'org': int(parts[1]),
            'username': parts[4].strip()
        })
    except Exception as e:
        errors.append(e)
        continue
    
    if len(errors) > 4:
        break

# %%
print(len(d))
d[:5]
# Out:
# 1603
# [{'org': 97, 'username': 'NULL'},
#  {'org': 140, 'username': 'heidi.morris@qgiv.com'},
#  {'org': 144, 'username': 'ammon.lowman@qgiv.com'},
#  {'org': 153, 'username': 'heidi.morris@qgiv.com'},
#  {'org': 177, 'username': 'ammon.lowman@qgiv.com'}]

# %% [markdown]
# # getting recent transactions

# %%
three_months_ago = datetime.date.today() + datetime.timedelta(-3 * 30)
q = '''select 
            org, 
            count(id) as trans_count 
        from transactions
        where date>={} and status='A'
        group by org'''.format(three_months_ago)
trans = redshift_query_read(q, schema='public')

# %%
trans['org'] = trans['org'].astype(int)
trans['trans_count'] = trans['trans_count'].astype(int)

# %%
trans.head()
# Out:
#    org  trans_count
# 0  243        40757
# 1  244        13597
# 2  595         5477
# 3  723         1411
# 4  582         4410

# %% [markdown]
# # filter out 0 trans orgs

# %%
print("{:,} orgs in low year round list".format(len(d)))
# Out:
# 1,603 orgs in low year round list

# %%
df = pd.DataFrame(d)
df.head(3)
# Out:
#    org               username
# 0   97                   NULL
# 1  140  heidi.morris@qgiv.com
# 2  144  ammon.lowman@qgiv.com

# %%
non_zero_orgs = [o for o in df['org'].tolist() if trans[trans['org']==o]['trans_count'].sum() > 10]
len(non_zero_orgs)
# Out:
# 1088

# %%
print("{} original entries".format(len(df)))
df = df[df['org'].isin(non_zero_orgs)]
print("{} entries after filer".format(len(df)))
# Out:
# 1603 original entries
# 1088 entries after filer

# %% [markdown]
# ## verify status, add org names for CX

# %% [markdown]
# ### add org status

# %%
q = "select * from organization"
org_statuses = redshift_query_read(q, schema='production')

# %%
org_statuses.tail(3)
# Out:
#           id         datecreated datelive state country  status  \
# 9869  447215 2021-06-10 12:39:39      NaT  None      US       4
# 9870  447231 2021-06-15 11:50:50      NaT  None      US       9
# 9871  447247 2021-06-18 12:33:33      NaT    FL      US       4
#
#                                website                       date
# 9869          https://www.capiusa.org/ 2021-06-22 03:02:26.778294
# 9870  https://www.portlandinsight.org/ 2021-06-22 03:02:26.778294
# 9871           https://afpflorida.org/ 2021-06-22 03:02:26.778294

# %%
def get_org_status(org):
    try:
        return org_statuses[org_statuses['id']==org]['status'].iloc[0]
    except:
        return np.nan
df['status'] = df['org'].apply(get_org_status)

# %%
df['status'].value_counts()
# Out:
# 1    1088
# Name: status, dtype: int64

# %%
df.columns = ['org', 'csm', 'status']
df.tail(3)
# Out:
#          org                    csm  status
# 1598  446493  ammon.lowman@qgiv.com       1
# 1600  446502   windy.keene@qgiv.com       1
# 1602  446514  heidi.morris@qgiv.com       1

# %% [markdown]
# ### add org name

# %%
list_files('qgiv-stats-data', search_key='names')
# Out:
# organizations.names.csv (2MB)
# --------------------------------------------------
# Matched files: 1 files (0.0GB)
# Bucket qgiv-stats-data contains 45 files (0.7GB)
# ['organizations.names.csv']

# %%
org_names = get_dataframe_from_file('qgiv-stats-data', 'organizations.names.csv')
org_names['id'] = org_names['id'].astype(int)
org_names.columns
# Out:
# Index(['id', 'org_name', 'tax_id', 'sic', 'csm', 'street', 'city', 'state',
#        'zip', 'country', 'live_date', 'signup_step_one',
#        'first_transaction_date', 'signup_implementation_time',
#        'go_live_implementation_time', 'status', 'pricing_package', 'reseller',
#        'previously_accepted_credit_online', 'segment', 'tags', 'date_closed',
#        'reason_closed', 'new_provider', 'additional_churn_info'],
#       dtype='object')

# %%
def get_org_name(org):
    try:
        return org_names[org_names['id']==org]['org_name'].iloc[0]
    except:
        return np.nan
df['name'] = df['org'].apply(get_org_name)

# %%
df.tail()
# Out:
#          org                    csm  status  \
# 1596  446479   windy.keene@qgiv.com       1
# 1597  446482  heidi.morris@qgiv.com       1
# 1598  446493  ammon.lowman@qgiv.com       1
# 1600  446502   windy.keene@qgiv.com       1
# 1602  446514  heidi.morris@qgiv.com       1
#
#                                                  name
# 1596                             YWCA Metro Vancouver
# 1597                               Ripple Productions
# 1598  Community Health Centers of Pinellas Foundation
# 1600                               ShoVal & More, NFP
# 1602                     Lewis & Clark Humane Society

# %%
df.to_csv("low_year_round.clean.csv", index=False)
