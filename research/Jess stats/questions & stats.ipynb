# %%
import sys
sys.path.insert(1, '../../scripts/')
from s3_support import *

import pandas as pd

# %% [markdown]
# # 1. Monitor health of texting
#
# - Total active donation forms
# - Total amount raised
# - \# of one-time donations

# %% [markdown]
# # 2. Benchmark against industry
#
# - Avg. one-time gift size
# - \# of recurring donations
# - Avg. recurring gift size

# %% [markdown]
# # 3. Do donors use giftassist when enabled?
#
# - % of donors who use giftassist

# %% [markdown]
# # 4. Do recurring nudges increase the liklihood that someone will upgrade from a one-time gift?
#
# - % of donors who upgrade to recurring gift with prompted

# %% [markdown]
# # 5. Does Smart Amounts help orgs raise more per donation?
#
# - \# of orgs using Smart Amounts
# - Avg raised using Smart Amounts

# %% [markdown]
# # 6. Do conditional fields help raise more money?
#
# - \# of forms using conditional fields
# - \$s raised by forms using conditional fields
# - \$s raised by forms not using conditional fields
# - Completion rate of forms using conditional fields
# - Completion rate of forms not using conditional fields

# %% [markdown]
# # 7. Do single step forms or multistep forms raise more?
#
# - \# of single step forms
# - \$s raised by single step forms
# - Completion rate of single step forms
# - \# of multi-step forms
# - \$s raised by multi-step forms
# - Completion rate of multi-step forms

# %% [markdown]
# # 8. Do donation amounts with images raise more?
#
# - \# of forms with donation amounts w/images
# - \$s raised by donation amounts w/images
# - \$s raised by donation amounts w/o images
