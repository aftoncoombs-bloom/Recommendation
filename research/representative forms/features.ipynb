# %%
import sys
sys.path.insert(1, '../../scripts/')
from s3_support import *

import pandas as pd
import numpy as np

# %% [markdown]
# Data built in <research.ipynb> and the isolated form ID's are stored in <filtered_forms.csv>.
#
# Data was built based upon activity from 2019-01-01 forward.

# %% [markdown]
# # load data

# %%
forms = pd.read_csv("filtered_forms.csv")
len(forms)
# Out:
# 9564

# %% [markdown]
# ## analytics

# %%
analytics = None
for year in [2019, 2020, 2021, 2022, 2023, 2024]:
    print("querying {}".format(year))
    q = '''select * from analytics_weekly where date_part('year', date)={}'''.format(year)
    d = redshift_query_read(q, schema='public')
    
    d = d[d['form'].isin(forms['form'].tolist())]
    analytics = pd.concat([d, analytics])
# Out:
# querying 2019
# querying 2020
# querying 2021
# querying 2022
# querying 2023
# querying 2024

# %%
print("{:,} entries".format(len(analytics)))
print("{}-{}".format(analytics['date'].min(), analytics['date'].max()))
print("{:,} unique forms".format(len(analytics['form'].unique())))

analytics.tail(2)
# Out:
# 967,395 entries
# 2019-01-07 00:00:00-2024-02-26 00:00:00
# 9,562 unique forms
#               date    org    form  product  vt_trans_count  \
# 1235252 2019-10-07  29728  948118        1               0
# 1235259 2019-12-02   1643  949702        3               0
#
#          don_form_trans_count  kiosk_trans_count  p2p_trans_count  \
# 1235252                     1                  0                0
# 1235259                     0                  0                0
#
#          mobile_trans_count  mobilevt_trans_count  ...  kiosk_trans_vol  \
# 1235252                   0                     0  ...              0.0
# 1235259                   0                     0  ...              0.0
#
#          p2p_trans_vol  mobile_trans_vol  mobilevt_trans_vol  sms_trans_vol  \
# 1235252            0.0               0.0                 0.0            0.0
# 1235259            0.0               0.0                 0.0            0.0
#
#          fb_trans_vol  one_time_trans_vol  one_time_trans_count  \
# 1235252           0.0               135.0                     1
# 1235259           0.0                 0.0                     0
#
#          rec_trans_vol  rec_trans_count
# 1235252            0.0                0
# 1235259            0.0                0
#
# [2 rows x 24 columns]

# %% [markdown]
# ## analytics p2p

# %%
analytics_p2p = None
for year in [2019, 2020, 2021, 2022, 2023, 2024]:
    print("querying {}".format(year))
    q = '''select * from analyticsp2p_weekly where date_part('year', date)={}'''.format(year)
    d = redshift_query_read(q, schema='public')
    
    d = d[d['form'].isin(forms['form'].tolist())]
    analytics_p2p = pd.concat([d, analytics_p2p])
# Out:
# querying 2019
# querying 2020
# querying 2021
# querying 2022
# querying 2023
# querying 2024

# %%
print("{:,} entries".format(len(analytics_p2p)))
print("{}-{}".format(analytics_p2p['date'].min(), analytics_p2p['date'].max()))
print("{:,} unique forms".format(len(analytics_p2p['form'].unique())))

analytics_p2p.tail(2)
# Out:
# 312,038 entries
# 2019-02-11 00:00:00-2024-02-26 00:00:00
# 2,683 unique forms
#              date    form     org  reg_count  sub_reg_count  teams_count  \
# 217352 2019-09-16  945730  443576          0              0            0
# 217367 2019-08-19  948889   29757          0              0            0
#
#         reg_volume  don_volume  don_count  class_count  ...  allows_social  \
# 217352         0.0         0.0          0            1  ...              0
# 217367         0.0         0.0          0            0  ...              0
#
#         social_templt_count  social_auto  pcnt_posts  mon_posts  count_posts  \
# 217352                    0            0           0          0            0
# 217367                    0            0           0          0            0
#
#         date_posts  email_templt_count  sponsors_count  inappr_content
# 217352           0                   0               0               0
# 217367           0                   0               0               0
#
# [2 rows x 44 columns]

# %% [markdown]
# ## analytics qgiv

# %%
analytics_qgiv = None
for year in [2019, 2020, 2021, 2022, 2023, 2024]:
    print("querying {}".format(year))
    q = '''select * from analyticsqgiv_weekly where date_part('year', date)={}'''.format(year)
    d = redshift_query_read(q, schema='public')
    
    d = d[d['form'].isin(forms['form'].tolist())]
    analytics_qgiv = pd.concat([d, analytics_qgiv])
# Out:
# querying 2019
# querying 2020
# querying 2021
# querying 2022
# querying 2023
# querying 2024

# %%
print("{:,} entries".format(len(analytics_qgiv)))
print("{}-{}".format(analytics_qgiv['date'].min(), analytics_qgiv['date'].max()))
print("{:,} unique forms".format(len(analytics_qgiv['form'].unique())))

analytics_qgiv.tail(2)
# Out:
# 580,503 entries
# 2019-02-11 00:00:00-2024-02-26 00:00:00
# 6,253 unique forms
#              date    form     org  pledges_count  events_count  \
# 911435 2019-04-15  899179  439324              0             0
# 911501 2019-03-04  942655  442129              0             0
#
#         events_priv_count  restrictions  amounts  ded_types  opt_ded_flds  \
# 911435                  0             0        4          0             0
# 911501                  0             0        0          0             0
#
#         ...  reg_count  dl_trans_volume  dl_trans_count  dl_new_rec_count  \
# 911435  ...          0              0.0               0                 0
# 911501  ...         26              0.0               0                 0
#
#         dl_new_rec_volume  cta_after  cta_before  conditional_fields  \
# 911435                0.0          0           0                   0
# 911501                0.0          0           0                   0
#
#         appearance  image_size
# 911435           0           0
# 911501           0           0
#
# [2 rows x 41 columns]

# %% [markdown]
# # analysis

# %%
analytics.groupby('form')['product'].first().value_counts()
# Out:
# 1    5914
# 3    2628
# 5    1019
# 2       1
# Name: product, dtype: int64

# %%
ad = analytics.drop(['org', 'form', 'date'], axis=1).describe().transpose().drop('count', axis=1)
ad['median'] = analytics.drop(['org', 'form', 'date'], axis=1).median()

# %%
cols = ('vt_trans_count', 'don_form_trans_count', 'kiosk_trans_count', 'p2p_trans_count', 'mobile_trans_count', 
        'mobilevt_trans_count', 'sms_trans_count', 'fb_trans_count', 'vt_trans_vol', 'don_form_trans_vol',
        'kiosk_trans_vol', 'p2p_trans_vol', 'mobile_trans_vol', 'mobilevt_trans_vol', 'sms_trans_vol',
        'fb_trans_vol', 'one_time_trans_vol', 'one_time_trans_count', 'rec_trans_vol', 'rec_trans_count')
col_str = ", ".join(["avg(cast({} as float)) as {}".format(c, c) for c in cols])
q = '''select {} from analytics_weekly where date>=2019'''.format(col_str)
avg_analytics = redshift_query_read(q, schema='public')

# %%
ad['mean all'] = avg_analytics.transpose()

# %%
ad
# Out:
#                            mean         std  min  25%  50%  75%        max  \
# product                1.953294    1.267474  1.0  1.0  1.0  3.0       5.00
# vt_trans_count         0.064160    1.700833  0.0  0.0  0.0  0.0     299.00
# don_form_trans_count   0.554920    4.755231  0.0  0.0  0.0  0.0    1040.00
# kiosk_trans_count      0.011027    0.576550  0.0  0.0  0.0  0.0     306.00
# p2p_trans_count        0.596975    7.546987  0.0  0.0  0.0  0.0     910.00
# mobile_trans_count     0.185455    2.540709  0.0  0.0  0.0  0.0     768.00
# mobilevt_trans_count   0.015544    0.816352  0.0  0.0  0.0  0.0     202.00
# sms_trans_count        0.020708    0.803257  0.0  0.0  0.0  0.0     233.00
# fb_trans_count         0.013539    0.694757  0.0  0.0  0.0  0.0     206.00
# vt_trans_vol          14.394235  648.833229  0.0  0.0  0.0  0.0  145273.00
# don_form_trans_vol    66.215807  772.232803  0.0  0.0  0.0  0.0  157667.00
# kiosk_trans_vol        0.910405   45.774488  0.0  0.0  0.0  0.0   14723.50
# p2p_trans_vol         46.497554  729.619476  0.0  0.0  0.0  0.0  267071.26
# mobile_trans_vol      18.023304  305.203171  0.0  0.0  0.0  0.0  114824.00
# mobilevt_trans_vol     1.643109  147.130190  0.0  0.0  0.0  0.0   82335.00
# sms_trans_vol          2.911782  154.314315  0.0  0.0  0.0  0.0   45283.25
# fb_trans_vol           0.702950   35.779012  0.0  0.0  0.0  0.0    9443.00
# one_time_trans_vol    66.215807  772.232803  0.0  0.0  0.0  0.0  157667.00
# one_time_trans_count   0.554920    4.755231  0.0  0.0  0.0  0.0    1040.00
# rec_trans_vol          0.409130   18.075062  0.0  0.0  0.0  0.0    5200.00
# rec_trans_count        0.005559    0.104598  0.0  0.0  0.0  0.0      11.00
#
#                       median   mean all
# product                  1.0        NaN
# vt_trans_count           0.0   0.028219
# don_form_trans_count     0.0   0.289713
# kiosk_trans_count        0.0   0.012031
# p2p_trans_count          0.0   0.154816
# mobile_trans_count       0.0   0.088685
# mobilevt_trans_count     0.0   0.005208
# sms_trans_count          0.0   0.007625
# fb_trans_count           0.0   0.002753
# vt_trans_vol             0.0   7.409370
# don_form_trans_vol       0.0  60.374908
# kiosk_trans_vol          0.0   1.708874
# p2p_trans_vol            0.0  14.358434
# mobile_trans_vol         0.0  13.455263
# mobilevt_trans_vol       0.0   0.692094
# sms_trans_vol            0.0   0.940874
# fb_trans_vol             0.0   0.154252
# one_time_trans_vol       0.0  60.374908
# one_time_trans_count     0.0   0.289713
# rec_trans_vol            0.0  15.231243
# rec_trans_count          0.0   0.271889

# %% [markdown]
# ## p2p

# %%
ap = analytics_p2p.drop(['org', 'form', 'date'], axis=1).describe().transpose().drop('count', axis=1)
ap['median'] = analytics_p2p.drop(['org', 'form', 'date'], axis=1).median()

# %%
cols = ('reg_count', 'sub_reg_count', 'teams_count', 'reg_volume', 'don_volume', 'don_count', 'class_count',
        'cat_count', 'promo_count', 'rest_count', 'amt_count', 'ded_count', 'fields', 'opt_fields',
        'req_fields', 'allows_reg_ind', 'allows_teams', 'allows_reg_team_create', 'allows_reg_team_join', 
        'allows_opt_reg_donation', 'allows_sub_reg', 'allows_sub_reg_pfp', 'allows_other_don_amt', 'allows_pfp_off_don',
        'allows_tfp_off_don', 'allows_soc_post_pfp_tcp', 'share_home', 'share_pfp', 'share_tfp', 'share_therm',
        'share_donation', 'allows_social', 'social_templt_count', 'social_auto', 'pcnt_posts', 'mon_posts',
        'count_posts', 'date_posts', 'email_templt_count', 'sponsors_count', 'inappr_content')
col_str = ", ".join(["avg(cast({} as float)) as {}".format(c, c) for c in cols])
q = '''select {} from analyticsp2p_weekly where date>=2019'''.format(col_str)
avg_p2p = redshift_query_read(q, schema='public')

# %%
ap['mean all'] = avg_p2p.transpose()

# %%
ap
# Out:
#                                mean          std  min  25%  50%   75%  \
# reg_count                  0.000000     0.000000  0.0  0.0  0.0   0.0
# sub_reg_count              0.105353     2.266880  0.0  0.0  0.0   0.0
# teams_count                0.124578     1.081353  0.0  0.0  0.0   0.0
# reg_volume                 0.000000     0.000000  0.0  0.0  0.0   0.0
# don_volume               131.422017  1225.769957  0.0  0.0  0.0   0.0
# don_count                  1.362026    10.564727  0.0  0.0  0.0   0.0
# class_count                2.126908     7.763552  0.0  0.0  0.0   1.0
# cat_count                  2.234286     2.434486  0.0  1.0  2.0   3.0
# promo_count                1.983835     8.520953  0.0  0.0  0.0   1.0
# rest_count                 0.083980     1.247812  0.0  0.0  0.0   0.0
# amt_count                  4.733830     1.328927  0.0  4.0  4.0   5.0
# ded_count                  0.654834     1.053805  0.0  0.0  0.0   1.0
# fields                     1.509284     2.460792  0.0  0.0  1.0   2.0
# opt_fields                 0.585852     1.321532  0.0  0.0  0.0   1.0
# req_fields                 0.922913     1.771818  0.0  0.0  0.0   1.0
# allows_reg_ind             0.770733     0.451730  0.0  1.0  1.0   1.0
# allows_teams               0.769980     0.452074  0.0  1.0  1.0   1.0
# allows_reg_team_create     0.794685     0.403932  0.0  1.0  1.0   1.0
# allows_reg_team_join       0.830764     0.374961  0.0  1.0  1.0   1.0
# allows_opt_reg_donation    0.939129     0.239094  0.0  1.0  1.0   1.0
# allows_sub_reg             1.000000     0.000000  1.0  1.0  1.0   1.0
# allows_sub_reg_pfp         0.001324     0.036357  0.0  0.0  0.0   0.0
# allows_other_don_amt       1.000000     0.000000  1.0  1.0  1.0   1.0
# allows_pfp_off_don         0.730882     0.443502  0.0  0.0  1.0   1.0
# allows_tfp_off_don         0.730882     0.443502  0.0  0.0  1.0   1.0
# allows_soc_post_pfp_tcp    0.000000     0.000000  0.0  0.0  0.0   0.0
# share_home                 0.000000     0.000000  0.0  0.0  0.0   0.0
# share_pfp                  0.000000     0.000000  0.0  0.0  0.0   0.0
# share_tfp                  0.000000     0.000000  0.0  0.0  0.0   0.0
# share_therm                0.000000     0.000000  0.0  0.0  0.0   0.0
# share_donation             0.000000     0.000000  0.0  0.0  0.0   0.0
# allows_social              0.000000     0.000000  0.0  0.0  0.0   0.0
# social_templt_count        0.000000     0.000000  0.0  0.0  0.0   0.0
# social_auto                0.042658     0.652096  0.0  0.0  0.0   0.0
# pcnt_posts                 0.011999     0.140789  0.0  0.0  0.0   0.0
# mon_posts                  0.000000     0.000000  0.0  0.0  0.0   0.0
# count_posts                0.020651     0.598314  0.0  0.0  0.0   0.0
# date_posts                 0.001840     0.051852  0.0  0.0  0.0   0.0
# email_templt_count         0.000000     0.000000  0.0  0.0  0.0   0.0
# sponsors_count             7.412584    12.822556  0.0  0.0  3.0  11.0
# inappr_content             0.008435     0.106238  0.0  0.0  0.0   0.0
#
#                               max  median   mean all
# reg_count                     0.0     0.0   0.000000
# sub_reg_count               466.0     0.0   0.043856
# teams_count                  84.0     0.0   0.040946
# reg_volume                    0.0     0.0   0.000000
# don_volume               263096.0     0.0  72.099187
# don_count                   804.0     0.0   0.680778
# class_count                 116.0     0.0   1.375796
# cat_count                    32.0     2.0   1.733895
# promo_count                 244.0     0.0   0.998044
# rest_count                   37.0     0.0   0.094839
# amt_count                    18.0     4.0   4.347030
# ded_count                     6.0     0.0   0.492200
# fields                       50.0     1.0   1.032220
# opt_fields                   17.0     0.0   0.373868
# req_fields                   47.0     0.0   0.658136
# allows_reg_ind                5.0     1.0   0.912564
# allows_teams                  5.0     1.0   0.889769
# allows_reg_team_create        1.0     1.0   0.693058
# allows_reg_team_join          1.0     1.0   0.723032
# allows_opt_reg_donation       1.0     1.0   0.914146
# allows_sub_reg                1.0     1.0   0.995307
# allows_sub_reg_pfp            1.0     0.0   0.098495
# allows_other_don_amt          1.0     1.0   0.999074
# allows_pfp_off_don            1.0     1.0   0.785891
# allows_tfp_off_don            1.0     1.0   0.785891
# allows_soc_post_pfp_tcp       0.0     0.0   0.000000
# share_home                    0.0     0.0   0.000000
# share_pfp                     0.0     0.0   0.000000
# share_tfp                     0.0     0.0   0.000000
# share_therm                   0.0     0.0   0.000000
# share_donation                0.0     0.0   0.000000
# allows_social                 0.0     0.0   0.016922
# social_templt_count           0.0     0.0   0.000000
# social_auto                  61.0     0.0   0.025915
# pcnt_posts                    4.0     0.0   0.011091
# mon_posts                     0.0     0.0   0.000000
# count_posts                  59.0     0.0   0.010146
# date_posts                    9.0     0.0   0.001387
# email_templt_count            0.0     0.0   0.000000
# sponsors_count              394.0     3.0   4.788812
# inappr_content                4.0     0.0   0.058850

# %% [markdown]
# ## qgiv

# %%
aq = analytics_qgiv.drop(['org', 'form', 'date'], axis=1).describe().transpose().drop('count', axis=1)
aq['median'] = analytics_qgiv.drop(['org', 'form', 'date'], axis=1).median()

# %%
cols = ['pledges_count', 'events_count', 'events_priv_count', 'restrictions', 'amounts', 'ded_types', 'opt_ded_flds', 'req_ded_flds',
        'opt_fields', 'req_fields', 'pledge_active', 'donation_active', 'multirestriction_system', 'min_amount', 'max_amount',
        'permit_anonymous', 'permit_recurring', 'permit_other_amount', 'permit_create_own_pledge', 'collect_company', 'collect_phone', 
        'collect_optin', 'collect_captcha', 'collect_address_mobile', 'enable_donorlogins', 'enable_sms', 'new_rec_volume',
        'new_rec_count', 'reg_count', 'dl_trans_volume', 'dl_trans_count', 'dl_new_rec_count', 'dl_new_rec_volume', 'cta_after',
        'cta_before', 'conditional_fields', 'appearance', 'image_size']
col_str = ", ".join(["avg(cast({} as float)) as {}".format(c, c) for c in cols])
q = '''select {} from analyticsqgiv_weekly where date>=2019'''.format(col_str)
avg_qgiv = redshift_query_read(q, schema='public')

# %%
aq['mean all'] = avg_qgiv.transpose()

# %%
aq
# Out:
#                                   mean           std  min  25%  50%  75%  \
# pledges_count                 0.693282      0.627782  0.0  0.0  1.0  1.0
# events_count                  0.596443      1.872823  0.0  0.0  0.0  1.0
# events_priv_count             0.031145      0.513377  0.0  0.0  0.0  0.0
# restrictions                  0.627955      2.906409  0.0  0.0  0.0  0.0
# amounts                       4.260006      2.350209  0.0  3.0  5.0  5.0
# ded_types                     0.438013      0.878539  0.0  0.0  0.0  0.0
# opt_ded_flds                  0.000000      0.000000  0.0  0.0  0.0  0.0
# req_ded_flds                  0.038725      0.326396  0.0  0.0  0.0  0.0
# opt_fields                    0.368244      1.140071  0.0  0.0  0.0  0.0
# req_fields                    0.257010      1.188785  0.0  0.0  0.0  0.0
# pledge_active                 0.071755      0.258082  0.0  0.0  0.0  0.0
# donation_active               0.711033      0.453283  0.0  0.0  1.0  1.0
# multirestriction_system       0.022241      0.147467  0.0  0.0  0.0  0.0
# min_amount                    5.568245    152.652499  0.0  1.0  1.0  1.0
# max_amount                12558.007857  93607.933124  0.0  0.0  0.0  0.0
# permit_anonymous              0.550288      0.497465  0.0  0.0  1.0  1.0
# permit_recurring              0.000000      0.000000  0.0  0.0  0.0  0.0
# permit_other_amount           0.851909      0.355190  0.0  1.0  1.0  1.0
# permit_create_own_pledge      0.456823      0.498133  0.0  0.0  0.0  1.0
# collect_company               0.187169      0.390047  0.0  0.0  0.0  0.0
# collect_phone                 0.327883      0.469442  0.0  0.0  0.0  1.0
# collect_optin                 1.551234      0.803542  0.0  2.0  2.0  2.0
# collect_captcha               0.000000      0.000000  0.0  0.0  0.0  0.0
# collect_address_mobile        1.187639      0.893565  0.0  0.0  2.0  2.0
# enable_donorlogins            0.399355      0.489766  0.0  0.0  0.0  1.0
# enable_sms                    0.193873      0.395331  0.0  0.0  0.0  0.0
# new_rec_volume                0.319590     68.095889  0.0  0.0  0.0  0.0
# new_rec_count                 0.002835      0.112181  0.0  0.0  0.0  0.0
# reg_count                     1.287408     13.042871  0.0  0.0  0.0  0.0
# dl_trans_volume              11.437904    227.521572  0.0  0.0  0.0  0.0
# dl_trans_count                0.092659      1.184380  0.0  0.0  0.0  0.0
# dl_new_rec_count              0.000803      0.033194  0.0  0.0  0.0  0.0
# dl_new_rec_volume             0.058525      3.821078  0.0  0.0  0.0  0.0
# cta_after                     0.039051      0.193716  0.0  0.0  0.0  0.0
# cta_before                    0.528452      0.499190  0.0  0.0  1.0  1.0
# conditional_fields            0.031140      0.325674  0.0  0.0  0.0  0.0
# appearance                    1.287353      0.767919  0.0  1.0  1.0  2.0
# image_size                    1.396999      0.790137  0.0  1.0  2.0  2.0
#
#                                 max  median      mean all
# pledges_count                 10.00     1.0      0.521577
# events_count                 140.00     0.0      0.251871
# events_priv_count             31.00     0.0      0.017945
# restrictions                 121.00     0.0      0.756384
# amounts                       34.00     5.0      4.297034
# ded_types                      6.00     0.0      0.506061
# opt_ded_flds                   0.00     0.0      0.000000
# req_ded_flds                   7.00     0.0      0.036627
# opt_fields                    27.00     0.0      0.367848
# req_fields                    38.00     0.0      0.171498
# pledge_active                  1.00     0.0      0.123392
# donation_active                1.00     1.0      0.827234
# multirestriction_system        1.00     0.0      0.021098
# min_amount                 10000.00     1.0     17.239049
# max_amount                999999.99     0.0  13799.930002
# permit_anonymous               1.00     1.0      0.512661
# permit_recurring               0.00     0.0      0.000000
# permit_other_amount            1.00     1.0      0.898329
# permit_create_own_pledge       1.00     0.0      0.558555
# collect_company                1.00     0.0      0.175133
# collect_phone                  1.00     0.0      0.362224
# collect_optin                  2.00     2.0      1.399487
# collect_captcha                0.00     0.0      0.000000
# collect_address_mobile         2.00     2.0      0.809046
# enable_donorlogins             1.00     0.0      0.444691
# enable_sms                     1.00     0.0      0.178461
# new_rec_volume             50000.00     0.0      4.210922
# new_rec_count                 63.00     0.0      0.031965
# reg_count                   2542.00     0.0      0.258352
# dl_trans_volume            46967.20     0.0     19.421949
# dl_trans_count               280.00     0.0      0.150170
# dl_new_rec_count               5.00     0.0      0.006203
# dl_new_rec_volume           1040.00     0.0      1.290991
# cta_after                      1.00     0.0      0.028279
# cta_before                     1.00     1.0      0.366698
# conditional_fields            18.00     0.0      0.030845
# appearance                     2.00     1.0      1.048687
# image_size                     2.00     2.0      1.096785

# %% [markdown]
# ## smart amounts

# %%
q = '''select distinct(form) from syslog_logs where message like '%Smart Amount%' '''
sa_forms = redshift_query_read(q, schema='production')

# %%
q = '''select distinct(form) from transactions where status='A' and year>='2019' '''
active_forms = redshift_query_read(q, schema='production')

# %%
len_active_forms = len(active_forms)
len_sa_forms = len(sa_forms)
perc_sa_forms = (len_sa_forms / len_active_forms)

len_sa_forms_fltrd = len([f for f in forms['form'].unique().tolist() if f in sa_forms['form'].tolist()])
perc_sa_forms_fltrd = (len_sa_forms_fltrd / len(forms['form'].unique().tolist()))

print("forms engageed with smart amounts: {:,} ({:.1f}% of active forms)".format(len_sa_forms, perc_sa_forms * 100.))
print("filtered forms engaged with smart amounts: {:,} ({:.1f}% of filtered forms)".format(len_sa_forms_fltrd, perc_sa_forms_fltrd * 100.))
# Out:
# forms engageed with smart amounts: 522 (1.1% of active forms)
# filtered forms engaged with smart amounts: 73 (0.8% of filtered forms)
