# %% [markdown]
# * Overall conversion rate on forms with One Time only vs. overall conversion rate on forms with One Time + Recurring
#     * Hoping this would tell us if even having recurring available as an option affects overall conversion?
#
# * Conversion rate of recurring gifts on forms with Recurring Nudge vs. without
#     * Only looking at forms that have one time and recurring enabled as an option
#     * Hoping this would tell us if the recurring nudge is effective at converting more recurring gifts?
#
# * Conversion rate of recurring gifts on forms with Recurring Modal vs. without
#     * Only looking at forms that have one time and recurring enabled as an option
#     * Hoping this would tell us if the recurring modal is effective at converting more recurring gifts?
#
# Data built in:
# _research/new forms/build/report - new settings.ipynb_

# %% [markdown]
# Conversion (all)
#
# |             | Recurring | One time | Overall |
# |-------------|------------|---------|---------|
# | CTA (either) |   0.29%   |  6.21%  |   6.50% |
# | CTA after   |   0.52%   |  7.23%   |   7.75% |
# | CTA before  |   0.28%   |  6.20%   |   6.49% |
# | No CTA      |   0.25%   |  4.29%   |   4.52% |
#
#
# Conversion (one time only vs w/ recurring)
#
# - One time only: 3.16%
# - One time + recurring: 10.01%
#
# Conversion (forms w/ one time + recurring)
#
# |             | Recurring | One time | Overall |
# |-------------|------------|---------|---------|
# | CTA (either) |   0.96%   |  9.68%  |   10.64% |
# | CTA after   |   1.03%   |  9.67%   |   10.71% |
# | CTA before  |   0.95%   |  9.67%   |   10.62% |
# | No CTA      |   1.12%   |  8.82%   |   9.95% |
#
# One time/recurring
#
# - CTA (either): 19.66
# - No CTA: 12.80

# %% [markdown]
# |             | Recurring | One time | Overall |
# |-------------|------------|---------|---------|
# | CTA (either) |   0.78%   |  6.70%  |   7.48% |
# | CTA after   |   0.85%   |  6.96%   |   7.81% |
# | CTA before  |   0.78%   |  6.70%   |   7.48% |
# | No CTA      |   0.86%   |  6.29%   |   7.16% |
